# %%
pip install tensorflow==2.12.0
# Out:
# Collecting tensorflow==2.12.0
#   Downloading tensorflow-2.12.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (585.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 585.9/585.9 MB 2.6 MB/s eta 0:00:00
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0) (23.5.26)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0) (0.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0) (1.57.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0) (3.9.0)
# Requirement already satisfied: jax>=0.3.15 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0) (0.4.14)
# Collecting keras<2.13,>=2.12.0 (from tensorflow==2.12.0)
#   Downloading keras-2.12.0-py2.py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 46.9 MB/s eta 0:00:00
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0) (16.0.6)
# Requirement already satisfied: numpy<1.24,>=1.22 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0) (1.23.5)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0) (23.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0) (1.16.0)
# Collecting tensorboard<2.13,>=2.12 (from tensorflow==2.12.0)
#   Downloading tensorboard-2.12.3-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 110.1 MB/s eta 0:00:00
# Collecting tensorflow-estimator<2.13,>=2.12.0 (from tensorflow==2.12.0)
#   Downloading tensorflow_estimator-2.12.0-py2.py3-none-any.whl (440 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 440.7/440.7 kB 45.8 MB/s eta 0:00:00
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0) (2.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0) (4.5.0)
# Collecting wrapt<1.15,>=1.11.0 (from tensorflow==2.12.0)
#   Downloading wrapt-1.14.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 9.5 MB/s eta 0:00:00
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0) (0.33.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow==2.12.0) (0.41.2)
# Requirement already satisfied: ml-dtypes>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from jax>=0.3.15->tensorflow==2.12.0) (0.2.0)
# Requirement already satisfied: scipy>=1.7 in /usr/local/lib/python3.10/dist-packages (from jax>=0.3.15->tensorflow==2.12.0) (1.10.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow==2.12.0) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow==2.12.0) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow==2.12.0) (3.4.4)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow==2.12.0) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow==2.12.0) (0.7.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow==2.12.0) (2.3.7)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow==2.12.0) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow==2.12.0) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow==2.12.0) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow==2.12.0) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow==2.12.0) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow==2.12.0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow==2.12.0) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow==2.12.0) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow==2.12.0) (2.1.3)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow==2.12.0) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow==2.12.0) (3.2.2)
# Installing collected packages: wrapt, tensorflow-estimator, keras, tensorboard, tensorflow
#   Attempting uninstall: wrapt
#     Found existing installation: wrapt 1.15.0
#     Uninstalling wrapt-1.15.0:
#       Successfully uninstalled wrapt-1.15.0
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.13.0
#     Uninstalling tensorflow-estimator-2.13.0:
#       Successfully uninstalled tensorflow-estimator-2.13.0
#   Attempting uninstall: keras
#     Found existing installation: keras 2.13.1
#     Uninstalling keras-2.13.1:
#       Successfully uninstalled keras-2.13.1
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.13.0
#     Uninstalling tensorboard-2.13.0:
#       Successfully uninstalled tensorboard-2.13.0
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.13.0
#     Uninstalling tensorflow-2.13.0:
#       Successfully uninstalled tensorflow-2.13.0
# Successfully installed keras-2.12.0 tensorboard-2.12.3 tensorflow-2.12.0 tensorflow-estimator-2.12.0 wrapt-1.14.1

# %%
# libraries
import os
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.base import BaseEstimator
import time

#Visualizers
from yellowbrick.classifier import ClassificationReport
from yellowbrick.classifier import ClassPredictionError
from yellowbrick.classifier import ConfusionMatrix
from yellowbrick.classifier import ROCAUC
from yellowbrick.classifier import PrecisionRecallCurve
import matplotlib.pyplot as plt

#Metrics
#Metrics
from sklearn.metrics import accuracy_score
from sklearn.metrics import cohen_kappa_score
from sklearn.metrics import hamming_loss
from sklearn.metrics import log_loss
from sklearn.metrics import zero_one_loss
from sklearn.metrics import matthews_corrcoef
from sklearn.metrics import precision_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import recall_score
from sklearn.metrics import classification_report



#Classifiers
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn import svm
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.tree import DecisionTreeClassifier

#Neural Network
from tensorflow.keras.layers import Input
from tensorflow.keras.layers import Dense,LSTM
from tensorflow.keras.layers import Conv1D
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
from tensorflow.keras.layers import Lambda, Layer, ReLU
from keras.models import load_model
import tensorflow as tf
from tensorflow.keras.losses import sparse_categorical_crossentropy
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import Conv1D, GlobalMaxPooling1D,Concatenate

import warnings
warnings.filterwarnings('ignore')

# %%
from keras import optimizers

# %%
import tensorflow
import os
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Conv2D, Dense, Input, Reshape, Lambda, Layer, Flatten, BatchNormalization,AveragePooling2D
from tensorflow.keras import backend as K
import matplotlib.pyplot as plt
import numpy as np
from keras.datasets import mnist

from keras import initializers

from keras.utils import to_categorical
from keras.layers.core import Activation

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data_path6 = '/content/drive/MyDrive/AlzheimerCodesDatosPlanos/BasesDeDatos/ADNI/ADNIMERGE.csv'
figures_path = './figures'

# %%
if not os.path.exists(figures_path):
    os.makedirs(figures_path)
if not os.path.exists(figures_path+"/6FP"):
    os.makedirs(figures_path+"/6FP")

# %%
import pandas as pd

Data = pd.read_csv(data_path6)
# Out:
# <ipython-input-4-f0cac09f77d5>:3: DtypeWarning: Columns (18,19,20,103,104) have mixed types. Specify dtype option on import or set low_memory=False.
#   Data = pd.read_csv(data_path6)

# %%
Data
# Out:
#         RID        PTID VISCODE  SITE COLPROT ORIGPROT    EXAMDATE DX_bl  \
# 0         2  011_S_0002      bl    11   ADNI1    ADNI1  2005-09-08    CN
# 1         3  011_S_0003      bl    11   ADNI1    ADNI1  2005-09-12    AD
# 2         3  011_S_0003     m06    11   ADNI1    ADNI1  2006-03-13    AD
# 3         3  011_S_0003     m12    11   ADNI1    ADNI1  2006-09-12    AD
# 4         3  011_S_0003     m24    11   ADNI1    ADNI1  2007-09-12    AD
# ...     ...         ...     ...   ...     ...      ...         ...   ...
# 13910  4384  029_S_4384     m84    29   ADNI3    ADNI2  2019-04-09    CN
# 13911  6703  135_S_6703      bl   135   ADNI3    ADNI3  2019-04-09   NaN
# 13912  6145  014_S_6145     m12    14   ADNI3    ADNI3  2019-04-09    CN
# 13913  6148  014_S_6148     m12    14   ADNI3    ADNI3  2019-04-05   SMC
# 13914  6273  100_S_6273     m12   100   ADNI3    ADNI3  2019-04-05   SMC
#
#         AGE PTGENDER  ...  TAU_bl PTAU_bl   FDG_bl PIB_bl  AV45_bl  Years_bl  \
# 0      74.3     Male  ...     NaN     NaN  1.36665    NaN      NaN  0.000000
# 1      81.3     Male  ...   239.7   22.83  1.08355    NaN      NaN  0.000000
# 2      81.3     Male  ...   239.7   22.83  1.08355    NaN      NaN  0.498289
# 3      81.3     Male  ...   239.7   22.83  1.08355    NaN      NaN  0.999316
# 4      81.3     Male  ...   239.7   22.83  1.08355    NaN      NaN  1.998630
# ...     ...      ...  ...     ...     ...      ...    ...      ...       ...
# 13910  62.3     Male  ...   109.3    9.86  1.12969    NaN  1.06225  7.167690
# 13911  62.7   Female  ...     NaN     NaN      NaN    NaN      NaN  0.000000
# 13912  70.3   Female  ...     NaN     NaN      NaN    NaN      NaN  1.073240
# 13913  81.5   Female  ...     NaN     NaN      NaN    NaN      NaN  1.081450
# 13914  65.8   Female  ...     NaN     NaN      NaN    NaN      NaN  0.980151
#
#        Month_bl  Month   M           update_stamp
# 0       0.00000      0   0  2019-02-14 23:58:27.0
# 1       0.00000      0   0  2019-02-14 23:58:27.0
# 2       5.96721      6   6  2019-02-14 23:58:27.0
# 3      11.96720     12  12  2019-02-14 23:58:27.0
# 4      23.93440     24  24  2019-02-14 23:58:27.0
# ...         ...    ...  ..                    ...
# 13910  85.83610     84  84  2019-04-10 04:36:05.0
# 13911   0.00000      0   0  2019-04-10 04:36:10.0
# 13912  12.85250     12  12  2019-04-11 04:36:24.0
# 13913  12.95080     12  12  2019-04-11 04:36:24.0
# 13914  11.73770     12  12  2019-04-11 04:36:24.0
#
# [13915 rows x 113 columns]

# %%
df=Data[["AGE","PTGENDER","PTEDUCAT", "PTMARRY","APOE4",
        "ADAS11","ADAS13","ADASQ4","MMSE","FAQ", "MOCA",
        "CDRSB","RAVLT_immediate","RAVLT_learning","RAVLT_forgetting",
        "RAVLT_perc_forgetting","LDELTOTAL", "TRABSCOR","mPACCdigit"
        ,"mPACCtrailsB","Ventricles", "Hippocampus","WholeBrain", "Entorhinal",
        "Fusiform", "MidTemp", "ICV","DX_bl"]]

# %%
from sklearn.preprocessing import LabelEncoder

# %%
LabelEncoder_1=LabelEncoder()
df["PTGENDER"]=LabelEncoder_1.fit_transform(df["PTGENDER"])
LabelEncoder_1=LabelEncoder()
df["PTMARRY"]=LabelEncoder_1.fit_transform(df["PTMARRY"])
# Out:
# <ipython-input-7-440c7344052d>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["PTGENDER"]=LabelEncoder_1.fit_transform(df["PTGENDER"])
# <ipython-input-7-440c7344052d>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["PTMARRY"]=LabelEncoder_1.fit_transform(df["PTMARRY"])

# %%
df=df.dropna()

# %%
df
# Out:
#         AGE  PTGENDER  PTEDUCAT  PTMARRY  APOE4  ADAS11  ADAS13  ADASQ4  MMSE  \
# 76     67.5         1        16        2    0.0     3.0     5.0     1.0  30.0
# 77     68.5         1        20        1    0.0     4.0     7.0     3.0  30.0
# 126    70.9         0        13        4    0.0     7.0     9.0     2.0  27.0
# 127    80.2         1        19        2    1.0     3.0    10.0     5.0  29.0
# 138    71.8         0        15        4    1.0     7.0    10.0     3.0  24.0
# ...     ...       ...       ...      ...    ...     ...     ...     ...   ...
# 13141  66.5         1        20        1    0.0     2.0     4.0     2.0  29.0
# 13144  66.5         1        20        1    0.0     3.0     4.0     1.0  30.0
# 13146  66.5         1        20        1    0.0     4.0     5.0     1.0  29.0
# 13147  66.5         1        20        1    0.0     5.0     5.0     0.0  30.0
# 13148  55.9         1        19        1    0.0    13.0    20.0     5.0  28.0
#
#         FAQ  ...  mPACCdigit  mPACCtrailsB  Ventricles  Hippocampus  \
# 76      0.0  ...    3.090790       2.40998     33185.0       8297.0
# 77      0.0  ...    3.603210       4.17904     21327.0       7654.0
# 126     0.0  ...   -3.295350      -3.06194     14066.0       6798.0
# 127     0.0  ...   -3.078400      -3.24437     30975.0       7480.0
# 138     1.0  ...  -10.478300      -8.66212     29814.0       6456.0
# ...     ...  ...         ...           ...         ...          ...
# 13141   0.0  ...    0.336098       1.11248     50946.0       7841.0
# 13144   0.0  ...    2.294010       3.13929     53954.0       7611.0
# 13146   2.0  ...    1.075870       2.46593     56610.0       7718.0
# 13147   0.0  ...    5.025750       5.42834     58940.0       7302.0
# 13148  19.0  ...   -4.296540      -6.53101     51726.0       7001.0
#
#        WholeBrain  Entorhinal  Fusiform  MidTemp        ICV  DX_bl
# 76      1165500.0      4946.0   20147.0  21194.0  1656460.0    SMC
# 77      1081140.0      4065.0   17964.0  18611.0  1508210.0    SMC
# 126      842989.0      2816.0   11687.0  13712.0  1248940.0     CN
# 127     1022610.0      4313.0   19821.0  17272.0  1461910.0    SMC
# 138      980388.0      3700.0   15637.0  16900.0  1305420.0    SMC
# ...           ...         ...       ...      ...        ...    ...
# 13141   1144970.0      3696.0   20021.0  20721.0  1630490.0     CN
# 13144   1084980.0      3586.0   20337.0  21149.0  1633240.0     CN
# 13146   1077610.0      3285.0   20223.0  20725.0  1630500.0     CN
# 13147   1059770.0      3577.0   19839.0  20657.0  1628540.0     CN
# 13148   1090370.0      3872.0   19196.0  16355.0  1544180.0   LMCI
#
# [1990 rows x 28 columns]

# %%
df.drop(df[df['DX_bl']=="SMC"].index,inplace=True)
df.drop(df[df['DX_bl']=="AD"].index,inplace=True)

# %%
Labels = df['DX_bl'].values
Features = df.drop(['DX_bl'],axis=1).values


print('Features shape:', Features.shape)
print('Labels shape:', Labels.shape)
# Out:
# Features shape: (1724, 27)
# Labels shape: (1724,)

# %%
df['DX_bl'].value_counts()
# Out:
# EMCI    696
# CN      583
# LMCI    445
# Name: DX_bl, dtype: int64

# %%
Features
# Out:
# array([[7.09000e+01, 0.00000e+00, 1.30000e+01, ..., 1.16870e+04,
#         1.37120e+04, 1.24894e+06],
#        [7.29000e+01, 1.00000e+00, 1.60000e+01, ..., 1.82410e+04,
#         2.24400e+04, 1.68850e+06],
#        [7.06000e+01, 1.00000e+00, 1.60000e+01, ..., 1.99990e+04,
#         2.16360e+04, 1.52995e+06],
#        ...,
#        [6.65000e+01, 1.00000e+00, 2.00000e+01, ..., 2.02230e+04,
#         2.07250e+04, 1.63050e+06],
#        [6.65000e+01, 1.00000e+00, 2.00000e+01, ..., 1.98390e+04,
#         2.06570e+04, 1.62854e+06],
#        [5.59000e+01, 1.00000e+00, 1.90000e+01, ..., 1.91960e+04,
#         1.63550e+04, 1.54418e+06]])

# %%
for i in range(len(Labels)):
  if Labels[i]=="EMCI":
    Labels[i]=0
  if Labels[i]=="CN":
    Labels[i]=1

  if Labels[i]=="LMCI":
    Labels[i]=2

# %%
LabelDataFrame=pd.DataFrame(Labels)

# %%
LabelDataFrame
# Out:
#       0
# 0     1
# 1     1
# 2     1
# 3     1
# 4     1
# ...  ..
# 1719  1
# 1720  1
# 1721  1
# 1722  1
# 1723  2
#
# [1724 rows x 1 columns]

# %%
#Write function for class-centric metrics
# Classification report
def CR_viz():
    def Class_report(model,classes):
        visualizer = ClassificationReport(model, classes=classes, support=True)
        train_start_time = time.time()
        visualizer.fit(X_train, y_train)  # Fit the visualizer and the model
        print(f'Train runtime: {time.time()-train_start_time}')
        test_start_time = time.time()
        visualizer.score(X_test, y_test)  # Evaluate the model on the test data
        print(f'Test runtime: {time.time()-test_start_time}')
        return visualizer.poof()
    for name, classifier in zip(names, classifiers):
        fig, ax = plt.subplots(nrows=1, ncols=1 )
        Class_report(classifier,classes)
        #fig.savefig(figures_path+"/"+str(len(classes))+"FP/"+name+"_CR.pdf")

#Class Prediction Error
def CPE_viz():
    def CPE(model,classes):
        visualizer = ClassPredictionError(model, classes=classes)
        visualizer.fit(X_train, y_train)  # Fit the visualizer and the model
        visualizer.score(X_test, y_test)  # Evaluate the model on the test data
        return visualizer.poof()
    for name, classifier in zip(names, classifiers):
        fig, ax = plt.subplots(nrows=1, ncols=1 )
        CPE(classifier,classes)
        #fig.savefig(figures_path+"/"+str(len(classes))+"FP/"+name+"_CPE.pdf")

#Confusion matrix
def CM_viz():
    def CM(model,classes):
        visualizer = ConfusionMatrix(model, classes=classes, percent=True)
        visualizer.fit(X_train, y_train)  # Fit the visualizer and the model
        visualizer.score(X_test, y_test)  # Evaluate the model on the test data
        return visualizer.poof()
    for name, classifier in zip(names, classifiers):
        fig, ax = plt.subplots(nrows=1, ncols=1 )
        CM(classifier,classes)
        #fig.savefig(figures_path+"/"+str(len(classes))+"FP/"+name+"_CM.pdf")

#ROC-AUC
def ROC_viz():
    def ROC(model,classes):
        visualizer = ROCAUC(model, classes=classes)
        visualizer.fit(X_train, y_train)  # Fit the visualizer and the model
        visualizer.score(X_test, y_test)  # Evaluate the model on the test data
        return visualizer.poof()
    for name, classifier in zip(names, classifiers):
        fig, ax = plt.subplots(nrows=1, ncols=1 )
        ROC(classifier,classes)
        #fig.savefig(figures_path+"/"+str(len(classes))+"FP/"+name+"_ROC.pdf")

#Precision Recall Curve
def PRC_viz():
    def PRC(model,classes):
        visualizer = PrecisionRecallCurve(model,classes=classes, per_class=True, iso_f1_curves=False,
    fill_area=False, micro=False)
        visualizer.fit(X_train, y_train)  # Fit the visualizer and the model
        visualizer.score(X_test, y_test)  # Evaluate the model on the test data
        return visualizer.poof()
    for name, classifier in zip(names, classifiers):
        fig, ax = plt.subplots(nrows=1, ncols=1 )
        PRC(classifier,classes)
        #fig.savefig(figures_path+"/"+str(len(classes))+"FP/"+name+"_PRC.pdf")

# %%
LabelDataFrame[0].value_counts()
# Out:
# 0    696
# 1    583
# 2    445
# Name: 0, dtype: int64

# %%
from sklearn.utils.multiclass import type_of_target

Labels= Labels[:].astype(int)


from imblearn.over_sampling import SMOTE

sm = SMOTE(random_state=45)

X_sm, y_sm = sm.fit_resample(Features, Labels)

print(f'''Shape of X before SMOTE: {Features.shape}
Shape of X after SMOTE: {X_sm.shape}''')
X_train, X_test, y_train, y_test = train_test_split(X_sm, y_sm, test_size=0.2, random_state=42)

print('Train data shape:', X_train.shape)
print('Train labels shape:', y_train.shape)
print('Test data shape:', X_test.shape)
print('Test labels shape:', y_test.shape)
# Out:
# Shape of X before SMOTE: (1724, 27)
# Shape of X after SMOTE: (2088, 27)
# Train data shape: (1670, 27)
# Train labels shape: (1670,)
# Test data shape: (418, 27)
# Test labels shape: (418,)

# %%
scaler = StandardScaler().fit(X_train)

X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
X_train.shape
# Out:
# (1670, 27)

# %%
X_train=np.expand_dims(X_train, axis=-1)
X_test=np.expand_dims(X_test, axis=-1)

# %%
X_train.shape
# Out:
# (1670, 27, 1)

# %%
#classes
classes = [0, 1, 2]

# %%
y_train[:].dtype
# Out:
# dtype('int64')

# %%
y_test[:].dtype
# Out:
# dtype('int64')

# %%
from sklearn.utils.multiclass import type_of_target
target_type = type_of_target(y_train[:])
print("Type of target:", target_type)
y_train= y_train[:].astype(int)
y_test=y_test[:].astype(int)
# Out:
# Type of target: multiclass

# %%
type_of_target(y_train)
# Out:
# 'multiclass'

# %%
type_of_target(y_test)
# Out:
# 'multiclass'

# %%
# Write function for aggregate metrics
def classifier_metrics():
    def metrics(model):
        #     model=model_name()
        model.fit(X_train, y_train)  # Fit the visualizer and the model
        y_pred = model.predict(X_test)
       # model.save('modeloEpilepsia.h5')
        try:
            y_prob = model.predict_proba(X_test)
            log_metric = log_loss(y_test,y_prob)
        except:
            y_prob = "Not probablistic"
            log_metric = 0
        else:
            y_pred = model.predict(X_test)

        acc_score=accuracy_score(y_test,y_pred)
        clc=classification_report(y_test, y_pred,labels=[1, 2, 3],digits=4)
        print(clc)
        print('accuracy_score: {0:.4f}'.format(acc_score))
    for name in classifiers:
        print (str(name))
        metrics(name)
        print()
        print ("---------------------------------------------------------------------------------")

# %%
from keras.layers import GlobalAveragePooling2D,ReLU
num_clases=3
vec=16
class DigitCapsuleLayer(Layer):
    # creating a layer class in keras
    def __init__(self, **kwargs):
        super(DigitCapsuleLayer, self).__init__(**kwargs)
        self.kernel_initializer = initializers.get('glorot_uniform')

    def build(self, input_shape):
        # initialize weight matrix for each capsule in lower layer
        self.W = self.add_weight(shape = [1,1,num_clases, vec, 256], initializer = self.kernel_initializer, name = 'weights') #:c
        self.built = True

    def call(self, inputs):
        #print(inputs.shape)
        u = tf.reshape(inputs, (-1, 1, 256)) # u.shape: (None, 1152, 8) #:c

        u = tf.expand_dims(u, axis=-2) # u.shape: (None, 1152, 1, 8)
        #print(u.shape)
        u = tf.expand_dims(u, axis=-1) # u.shape: (None, 1152, 1, 8, 1)
        u_hat = tf.matmul(self.W, u) # u_hat.shape: (None, 1152, 10, 16, 1)
        u_hat = tf.squeeze(u_hat, [4]) # u_hat.shape: (None, 1152, 10, 16)
        b = tf.zeros(shape = [K.shape(inputs)[0],2, num_clases, 1])

# routing algorithm with updating coupling coefficient c, using scalar product b/w input capsule and output capsule
        for i in range(3-1):
            c = tf.nn.softmax(b, axis=-2) # c.shape: (None, 1152, 10, 1)
            s = tf.reduce_sum(tf.multiply(c, u_hat), axis=1, keepdims=True) # s.shape: (None, 1, 10, 16)
            v = squash(s) # v.shape: (None, 1, 10, 16)
            agreement = tf.squeeze(tf.matmul(tf.expand_dims(u_hat, axis=-1), tf.expand_dims(v, axis=-1), transpose_a=True), [4]) # agreement.shape: (None, 1152, 10, 1)
            b += agreement

        return v

    def compute_output_shape(self, input_shape):
        return tuple([None, num_clases, vec])

epsilon = 1e-7

def output_layer(inputs):
    return K.sqrt(K.sum(K.square(inputs), -1) + K.epsilon())

def squash(inputs):
    # take norm of input vectors
    squared_norm = tf.keras.backend.sum(tf.keras.backend.square(inputs), axis = -1, keepdims = True)

    # use the formula for non-linear function to return squashed output
    return ((squared_norm/(1+squared_norm))/(K.sqrt(squared_norm+K.epsilon())))*inputs

def safe_norm(v, axis=-1, epsilon=1e-7):
    v_ = tf.reduce_sum(tf.square(v), axis = axis, keepdims=True)
    return tf.sqrt(v_ + epsilon)

# %%
class KerasBatchClassifier(KerasClassifier, BaseEstimator):
    def __init__(self, model, **kwargs):
        super().__init__(model)
        self.fit_kwargs = kwargs
        self._estimator_type = 'classifier'

    def fit(self, x, y, *args, **kwargs):
        y = np.array(y)
        if len(y.shape) == 2 and y.shape[1] > 1:
          self.classes_ = np.arange(y.shape[1])
        elif (len(y.shape) == 2 and y.shape[1] == 1) or len(y.shape) == 1:
          self.classes_ = np.unique(y)
          y = np.searchsorted(self.classes_, y)
        else:
          raise ValueError('Invalid shape for y: ' + str(y.shape))
        self.n_classes_ = len(self.classes_)
        return super(KerasClassifier, self).fit(x, y, **self.fit_kwargs)


# RED NEURONAL
def FullyConnected():


  inputs = Input(shape=(X_train.shape[1],1), name="input_1")


  Layer_1=tf.keras.layers.Conv1D(8,3,activation="selu",padding="same")(inputs)


#16

  Layer_1=tf.keras.layers.Conv1D(16,3,activation="selu",padding="same")(Layer_1)

#32

  Layer_1=tf.keras.layers.Conv1D(32,3,activation="selu",padding="same")(Layer_1)
  Pool_1=tf.keras.layers.MaxPool1D(2)(Layer_1)
  Pool_1=tf.keras.layers.Dropout(rate=0.5)(Pool_1)

#64

  Layer_1=tf.keras.layers.Conv1D(64,3,activation="selu",padding="same")(Pool_1)
  Pool_1=tf.keras.layers.MaxPool1D(2)(Layer_1)
  Pool_1=tf.keras.layers.Dropout(rate=0.5)(Pool_1)

#128

  Layer_1=tf.keras.layers.Conv1D(128,3,activation="selu",padding="same")(Pool_1)
  Pool_1=tf.keras.layers.MaxPool1D(2)(Layer_1)
  Pool_1=tf.keras.layers.Dropout(rate=0.5)(Pool_1)

#256

  Layer_1=tf.keras.layers.Conv1D(256,3,activation="selu",padding="same")(Pool_1)
  Pool_1=tf.keras.layers.MaxPool1D(2)(Layer_1)
  Pool_1=tf.keras.layers.Dropout(rate=0.5)(Pool_1)

  squashed_output = tf.keras.layers.Lambda(squash)(Pool_1)
  digit_caps = DigitCapsuleLayer()(squashed_output)
  Acont= safe_norm(digit_caps)
  mast = tf.reshape(Acont, (-1,Acont.shape[2],Acont.shape[3]))
  outputs = tf.keras.layers.Lambda(output_layer)(mast)
  model = Model(inputs = inputs, outputs = outputs)

  optimizer=Adam(learning_rate=0.001)
  model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
  return model

# %%
classifiers=[KerasBatchClassifier(FullyConnected, epochs=500, batch_size=256, verbose=2)]
names = ['FNN']
classifier_metrics()
visualization =[CR_viz(),CPE_viz(),CM_viz(),ROC_viz()]
# Out:
# KerasBatchClassifier(build_fn=<function FullyConnected at 0x788cd2242200>)
# Epoch 1/500
# 7/7 - 13s - loss: 1.1295 - accuracy: 0.3629 - 13s/epoch - 2s/step
# Epoch 2/500
# 7/7 - 0s - loss: 1.0850 - accuracy: 0.3958 - 50ms/epoch - 7ms/step
# Epoch 3/500
# 7/7 - 0s - loss: 1.0457 - accuracy: 0.4563 - 51ms/epoch - 7ms/step
# Epoch 4/500
# 7/7 - 0s - loss: 0.9883 - accuracy: 0.5042 - 47ms/epoch - 7ms/step
# Epoch 5/500
# 7/7 - 0s - loss: 0.9523 - accuracy: 0.5323 - 48ms/epoch - 7ms/step
# Epoch 6/500
# 7/7 - 0s - loss: 0.9515 - accuracy: 0.5251 - 46ms/epoch - 7ms/step
# Epoch 7/500
# 7/7 - 0s - loss: 0.9326 - accuracy: 0.5491 - 45ms/epoch - 6ms/step
# Epoch 8/500
# 7/7 - 0s - loss: 0.9297 - accuracy: 0.5545 - 47ms/epoch - 7ms/step
# Epoch 9/500
# 7/7 - 0s - loss: 0.9241 - accuracy: 0.5527 - 48ms/epoch - 7ms/step
# Epoch 10/500
# 7/7 - 0s - loss: 0.9218 - accuracy: 0.5617 - 46ms/epoch - 7ms/step
# Epoch 11/500
# 7/7 - 0s - loss: 0.9037 - accuracy: 0.5814 - 47ms/epoch - 7ms/step
# Epoch 12/500
# 7/7 - 0s - loss: 0.9029 - accuracy: 0.5778 - 48ms/epoch - 7ms/step
# Epoch 13/500
# 7/7 - 0s - loss: 0.8790 - accuracy: 0.6042 - 46ms/epoch - 7ms/step
# Epoch 14/500
# 7/7 - 0s - loss: 0.8634 - accuracy: 0.6030 - 47ms/epoch - 7ms/step
# Epoch 15/500
# 7/7 - 0s - loss: 0.8621 - accuracy: 0.5988 - 48ms/epoch - 7ms/step
# Epoch 16/500
# 7/7 - 0s - loss: 0.8463 - accuracy: 0.6222 - 47ms/epoch - 7ms/step
# Epoch 17/500
# 7/7 - 0s - loss: 0.8423 - accuracy: 0.6126 - 47ms/epoch - 7ms/step
# Epoch 18/500
# 7/7 - 0s - loss: 0.8236 - accuracy: 0.6395 - 47ms/epoch - 7ms/step
# Epoch 19/500
# 7/7 - 0s - loss: 0.8222 - accuracy: 0.6228 - 46ms/epoch - 7ms/step
# Epoch 20/500
# 7/7 - 0s - loss: 0.8221 - accuracy: 0.6437 - 46ms/epoch - 7ms/step
# Epoch 21/500
# 7/7 - 0s - loss: 0.8186 - accuracy: 0.6371 - 47ms/epoch - 7ms/step
# Epoch 22/500
# 7/7 - 0s - loss: 0.8120 - accuracy: 0.6246 - 49ms/epoch - 7ms/step
# Epoch 23/500
# 7/7 - 0s - loss: 0.8075 - accuracy: 0.6497 - 47ms/epoch - 7ms/step
# Epoch 24/500
# 7/7 - 0s - loss: 0.7889 - accuracy: 0.6599 - 48ms/epoch - 7ms/step
# Epoch 25/500
# 7/7 - 0s - loss: 0.7843 - accuracy: 0.6551 - 47ms/epoch - 7ms/step
# Epoch 26/500
# 7/7 - 0s - loss: 0.7754 - accuracy: 0.6533 - 47ms/epoch - 7ms/step
# Epoch 27/500
# 7/7 - 0s - loss: 0.7599 - accuracy: 0.6635 - 47ms/epoch - 7ms/step
# Epoch 28/500
# 7/7 - 0s - loss: 0.7457 - accuracy: 0.6701 - 48ms/epoch - 7ms/step
# Epoch 29/500
# 7/7 - 0s - loss: 0.7549 - accuracy: 0.6665 - 50ms/epoch - 7ms/step
# Epoch 30/500
# 7/7 - 0s - loss: 0.7434 - accuracy: 0.6772 - 56ms/epoch - 8ms/step
# Epoch 31/500
# 7/7 - 0s - loss: 0.7574 - accuracy: 0.6659 - 54ms/epoch - 8ms/step
# Epoch 32/500
# 7/7 - 0s - loss: 0.7463 - accuracy: 0.6719 - 47ms/epoch - 7ms/step
# Epoch 33/500
# 7/7 - 0s - loss: 0.7262 - accuracy: 0.6856 - 48ms/epoch - 7ms/step
# Epoch 34/500
# 7/7 - 0s - loss: 0.7300 - accuracy: 0.6862 - 49ms/epoch - 7ms/step
# Epoch 35/500
# 7/7 - 0s - loss: 0.7287 - accuracy: 0.6928 - 49ms/epoch - 7ms/step
# Epoch 36/500
# 7/7 - 0s - loss: 0.7188 - accuracy: 0.6814 - 48ms/epoch - 7ms/step
# Epoch 37/500
# 7/7 - 0s - loss: 0.7157 - accuracy: 0.6964 - 50ms/epoch - 7ms/step
# Epoch 38/500
# 7/7 - 0s - loss: 0.7018 - accuracy: 0.6988 - 49ms/epoch - 7ms/step
# Epoch 39/500
# 7/7 - 0s - loss: 0.7103 - accuracy: 0.7048 - 48ms/epoch - 7ms/step
# Epoch 40/500
# 7/7 - 0s - loss: 0.7218 - accuracy: 0.6910 - 46ms/epoch - 7ms/step
# Epoch 41/500
# 7/7 - 0s - loss: 0.6958 - accuracy: 0.7060 - 49ms/epoch - 7ms/step
# Epoch 42/500
# 7/7 - 0s - loss: 0.7107 - accuracy: 0.6868 - 49ms/epoch - 7ms/step
# Epoch 43/500
# 7/7 - 0s - loss: 0.6912 - accuracy: 0.6934 - 46ms/epoch - 7ms/step
# Epoch 44/500
# 7/7 - 0s - loss: 0.6922 - accuracy: 0.7114 - 47ms/epoch - 7ms/step
# Epoch 45/500
# 7/7 - 0s - loss: 0.6931 - accuracy: 0.7000 - 49ms/epoch - 7ms/step
# Epoch 46/500
# 7/7 - 0s - loss: 0.6907 - accuracy: 0.7084 - 47ms/epoch - 7ms/step
# Epoch 47/500
# 7/7 - 0s - loss: 0.6944 - accuracy: 0.7030 - 47ms/epoch - 7ms/step
# Epoch 48/500
# 7/7 - 0s - loss: 0.6922 - accuracy: 0.7108 - 48ms/epoch - 7ms/step
# Epoch 49/500
# 7/7 - 0s - loss: 0.6848 - accuracy: 0.7126 - 49ms/epoch - 7ms/step
# Epoch 50/500
# 7/7 - 0s - loss: 0.6619 - accuracy: 0.7228 - 47ms/epoch - 7ms/step
# Epoch 51/500
# 7/7 - 0s - loss: 0.6635 - accuracy: 0.7204 - 46ms/epoch - 7ms/step
# Epoch 52/500
# 7/7 - 0s - loss: 0.6548 - accuracy: 0.7305 - 46ms/epoch - 7ms/step
# Epoch 53/500
# 7/7 - 0s - loss: 0.6704 - accuracy: 0.7132 - 49ms/epoch - 7ms/step
# Epoch 54/500
# 7/7 - 0s - loss: 0.6600 - accuracy: 0.7102 - 47ms/epoch - 7ms/step
# Epoch 55/500
# 7/7 - 0s - loss: 0.6646 - accuracy: 0.7240 - 47ms/epoch - 7ms/step
# Epoch 56/500
# 7/7 - 0s - loss: 0.6718 - accuracy: 0.7192 - 48ms/epoch - 7ms/step
# Epoch 57/500
# 7/7 - 0s - loss: 0.6543 - accuracy: 0.7401 - 47ms/epoch - 7ms/step
# Epoch 58/500
# 7/7 - 0s - loss: 0.6676 - accuracy: 0.7120 - 51ms/epoch - 7ms/step
# Epoch 59/500
# 7/7 - 0s - loss: 0.6535 - accuracy: 0.7132 - 44ms/epoch - 6ms/step
# Epoch 60/500
# 7/7 - 0s - loss: 0.6450 - accuracy: 0.7263 - 45ms/epoch - 6ms/step
# Epoch 61/500
# 7/7 - 0s - loss: 0.6665 - accuracy: 0.7060 - 47ms/epoch - 7ms/step
# Epoch 62/500
# 7/7 - 0s - loss: 0.6427 - accuracy: 0.7305 - 46ms/epoch - 7ms/step
# Epoch 63/500
# 7/7 - 0s - loss: 0.6590 - accuracy: 0.7204 - 44ms/epoch - 6ms/step
# Epoch 64/500
# 7/7 - 0s - loss: 0.6405 - accuracy: 0.7371 - 43ms/epoch - 6ms/step
# Epoch 65/500
# 7/7 - 0s - loss: 0.6394 - accuracy: 0.7413 - 42ms/epoch - 6ms/step
# Epoch 66/500
# 7/7 - 0s - loss: 0.6539 - accuracy: 0.7257 - 43ms/epoch - 6ms/step
# Epoch 67/500
# 7/7 - 0s - loss: 0.6437 - accuracy: 0.7311 - 46ms/epoch - 7ms/step
# Epoch 68/500
# 7/7 - 0s - loss: 0.6309 - accuracy: 0.7467 - 46ms/epoch - 7ms/step
# Epoch 69/500
# 7/7 - 0s - loss: 0.6227 - accuracy: 0.7485 - 45ms/epoch - 6ms/step
# Epoch 70/500
# 7/7 - 0s - loss: 0.6325 - accuracy: 0.7371 - 45ms/epoch - 6ms/step
# Epoch 71/500
# 7/7 - 0s - loss: 0.6344 - accuracy: 0.7389 - 46ms/epoch - 7ms/step
# Epoch 72/500
# 7/7 - 0s - loss: 0.6354 - accuracy: 0.7455 - 44ms/epoch - 6ms/step
# Epoch 73/500
# 7/7 - 0s - loss: 0.6412 - accuracy: 0.7371 - 44ms/epoch - 6ms/step
# Epoch 74/500
# 7/7 - 0s - loss: 0.6425 - accuracy: 0.7347 - 43ms/epoch - 6ms/step
# Epoch 75/500
# 7/7 - 0s - loss: 0.6229 - accuracy: 0.7329 - 43ms/epoch - 6ms/step
# Epoch 76/500
# 7/7 - 0s - loss: 0.6229 - accuracy: 0.7317 - 43ms/epoch - 6ms/step
# Epoch 77/500
# 7/7 - 0s - loss: 0.6198 - accuracy: 0.7437 - 44ms/epoch - 6ms/step
# Epoch 78/500
# 7/7 - 0s - loss: 0.6329 - accuracy: 0.7503 - 46ms/epoch - 7ms/step
# Epoch 79/500
# 7/7 - 0s - loss: 0.6395 - accuracy: 0.7293 - 46ms/epoch - 7ms/step
# Epoch 80/500
# 7/7 - 0s - loss: 0.6378 - accuracy: 0.7359 - 45ms/epoch - 6ms/step
# Epoch 81/500
# 7/7 - 0s - loss: 0.6194 - accuracy: 0.7569 - 45ms/epoch - 6ms/step
# Epoch 82/500
# 7/7 - 0s - loss: 0.6147 - accuracy: 0.7407 - 44ms/epoch - 6ms/step
# Epoch 83/500
# 7/7 - 0s - loss: 0.6112 - accuracy: 0.7467 - 45ms/epoch - 6ms/step
# Epoch 84/500
# 7/7 - 0s - loss: 0.6132 - accuracy: 0.7485 - 45ms/epoch - 6ms/step
# Epoch 85/500
# 7/7 - 0s - loss: 0.6239 - accuracy: 0.7461 - 44ms/epoch - 6ms/step
# Epoch 86/500
# 7/7 - 0s - loss: 0.6133 - accuracy: 0.7605 - 44ms/epoch - 6ms/step
# Epoch 87/500
# 7/7 - 0s - loss: 0.6229 - accuracy: 0.7383 - 43ms/epoch - 6ms/step
# Epoch 88/500
# 7/7 - 0s - loss: 0.6044 - accuracy: 0.7455 - 43ms/epoch - 6ms/step
# Epoch 89/500
# 7/7 - 0s - loss: 0.6105 - accuracy: 0.7419 - 46ms/epoch - 7ms/step
# Epoch 90/500
# 7/7 - 0s - loss: 0.5886 - accuracy: 0.7677 - 44ms/epoch - 6ms/step
# Epoch 91/500
# 7/7 - 0s - loss: 0.6077 - accuracy: 0.7545 - 43ms/epoch - 6ms/step
# Epoch 92/500
# 7/7 - 0s - loss: 0.5861 - accuracy: 0.7569 - 45ms/epoch - 6ms/step
# Epoch 93/500
# 7/7 - 0s - loss: 0.6104 - accuracy: 0.7551 - 46ms/epoch - 7ms/step
# Epoch 94/500
# 7/7 - 0s - loss: 0.5907 - accuracy: 0.7563 - 46ms/epoch - 7ms/step
# Epoch 95/500
# 7/7 - 0s - loss: 0.6090 - accuracy: 0.7431 - 45ms/epoch - 6ms/step
# Epoch 96/500
# 7/7 - 0s - loss: 0.6046 - accuracy: 0.7581 - 45ms/epoch - 6ms/step
# Epoch 97/500
# 7/7 - 0s - loss: 0.5838 - accuracy: 0.7593 - 43ms/epoch - 6ms/step
# Epoch 98/500
# 7/7 - 0s - loss: 0.5930 - accuracy: 0.7569 - 44ms/epoch - 6ms/step
# Epoch 99/500
# 7/7 - 0s - loss: 0.5890 - accuracy: 0.7659 - 42ms/epoch - 6ms/step
# Epoch 100/500
# 7/7 - 0s - loss: 0.5731 - accuracy: 0.7605 - 43ms/epoch - 6ms/step
# Epoch 101/500
# 7/7 - 0s - loss: 0.5998 - accuracy: 0.7593 - 44ms/epoch - 6ms/step
# Epoch 102/500
# 7/7 - 0s - loss: 0.5954 - accuracy: 0.7557 - 44ms/epoch - 6ms/step
# Epoch 103/500
# 7/7 - 0s - loss: 0.5942 - accuracy: 0.7569 - 44ms/epoch - 6ms/step
# Epoch 104/500
# 7/7 - 0s - loss: 0.5863 - accuracy: 0.7551 - 45ms/epoch - 6ms/step
# Epoch 105/500
# 7/7 - 0s - loss: 0.5794 - accuracy: 0.7671 - 44ms/epoch - 6ms/step
# Epoch 106/500
# 7/7 - 0s - loss: 0.5706 - accuracy: 0.7605 - 43ms/epoch - 6ms/step
# Epoch 107/500
# 7/7 - 0s - loss: 0.5831 - accuracy: 0.7683 - 45ms/epoch - 6ms/step
# Epoch 108/500
# 7/7 - 0s - loss: 0.5862 - accuracy: 0.7605 - 43ms/epoch - 6ms/step
# Epoch 109/500
# 7/7 - 0s - loss: 0.5835 - accuracy: 0.7557 - 44ms/epoch - 6ms/step
# Epoch 110/500
# 7/7 - 0s - loss: 0.5767 - accuracy: 0.7707 - 45ms/epoch - 6ms/step
# Epoch 111/500
# 7/7 - 0s - loss: 0.5746 - accuracy: 0.7707 - 43ms/epoch - 6ms/step
# Epoch 112/500
# 7/7 - 0s - loss: 0.5735 - accuracy: 0.7701 - 44ms/epoch - 6ms/step
# Epoch 113/500
# 7/7 - 0s - loss: 0.5700 - accuracy: 0.7671 - 44ms/epoch - 6ms/step
# Epoch 114/500
# 7/7 - 0s - loss: 0.5700 - accuracy: 0.7737 - 48ms/epoch - 7ms/step
# Epoch 115/500
# 7/7 - 0s - loss: 0.5720 - accuracy: 0.7665 - 45ms/epoch - 6ms/step
# Epoch 116/500
# 7/7 - 0s - loss: 0.5544 - accuracy: 0.7749 - 47ms/epoch - 7ms/step
# Epoch 117/500
# 7/7 - 0s - loss: 0.5599 - accuracy: 0.7754 - 43ms/epoch - 6ms/step
# Epoch 118/500
# 7/7 - 0s - loss: 0.5536 - accuracy: 0.7772 - 43ms/epoch - 6ms/step
# Epoch 119/500
# 7/7 - 0s - loss: 0.5673 - accuracy: 0.7695 - 44ms/epoch - 6ms/step
# Epoch 120/500
# 7/7 - 0s - loss: 0.5677 - accuracy: 0.7749 - 43ms/epoch - 6ms/step
# Epoch 121/500
# 7/7 - 0s - loss: 0.5423 - accuracy: 0.7922 - 42ms/epoch - 6ms/step
# Epoch 122/500
# 7/7 - 0s - loss: 0.5575 - accuracy: 0.7796 - 45ms/epoch - 6ms/step
# Epoch 123/500
# 7/7 - 0s - loss: 0.5730 - accuracy: 0.7719 - 44ms/epoch - 6ms/step
# Epoch 124/500
# 7/7 - 0s - loss: 0.5599 - accuracy: 0.7772 - 45ms/epoch - 6ms/step
# Epoch 125/500
# 7/7 - 0s - loss: 0.5537 - accuracy: 0.7832 - 44ms/epoch - 6ms/step
# Epoch 126/500
# 7/7 - 0s - loss: 0.5592 - accuracy: 0.7754 - 46ms/epoch - 7ms/step
# Epoch 127/500
# 7/7 - 0s - loss: 0.5810 - accuracy: 0.7533 - 46ms/epoch - 7ms/step
# Epoch 128/500
# 7/7 - 0s - loss: 0.5599 - accuracy: 0.7683 - 44ms/epoch - 6ms/step
# Epoch 129/500
# 7/7 - 0s - loss: 0.5570 - accuracy: 0.7749 - 43ms/epoch - 6ms/step
# Epoch 130/500
# 7/7 - 0s - loss: 0.5522 - accuracy: 0.7922 - 44ms/epoch - 6ms/step
# Epoch 131/500
# 7/7 - 0s - loss: 0.5595 - accuracy: 0.7713 - 44ms/epoch - 6ms/step
# Epoch 132/500
# 7/7 - 0s - loss: 0.5560 - accuracy: 0.7737 - 48ms/epoch - 7ms/step
# Epoch 133/500
# 7/7 - 0s - loss: 0.5614 - accuracy: 0.7713 - 45ms/epoch - 6ms/step
# Epoch 134/500
# 7/7 - 0s - loss: 0.5647 - accuracy: 0.7731 - 44ms/epoch - 6ms/step
# Epoch 135/500
# 7/7 - 0s - loss: 0.5393 - accuracy: 0.7814 - 44ms/epoch - 6ms/step
# Epoch 136/500
# 7/7 - 0s - loss: 0.5643 - accuracy: 0.7683 - 49ms/epoch - 7ms/step
# Epoch 137/500
# 7/7 - 0s - loss: 0.5580 - accuracy: 0.7719 - 53ms/epoch - 8ms/step
# Epoch 138/500
# 7/7 - 0s - loss: 0.5508 - accuracy: 0.7707 - 45ms/epoch - 6ms/step
# Epoch 139/500
# 7/7 - 0s - loss: 0.5657 - accuracy: 0.7659 - 45ms/epoch - 6ms/step
# Epoch 140/500
# 7/7 - 0s - loss: 0.5570 - accuracy: 0.7713 - 44ms/epoch - 6ms/step
# Epoch 141/500
# 7/7 - 0s - loss: 0.5666 - accuracy: 0.7683 - 43ms/epoch - 6ms/step
# Epoch 142/500
# 7/7 - 0s - loss: 0.5514 - accuracy: 0.7802 - 44ms/epoch - 6ms/step
# Epoch 143/500
# 7/7 - 0s - loss: 0.5381 - accuracy: 0.7940 - 45ms/epoch - 6ms/step
# Epoch 144/500
# 7/7 - 0s - loss: 0.5531 - accuracy: 0.7749 - 44ms/epoch - 6ms/step
# Epoch 145/500
# 7/7 - 0s - loss: 0.5487 - accuracy: 0.7814 - 43ms/epoch - 6ms/step
# Epoch 146/500
# 7/7 - 0s - loss: 0.5413 - accuracy: 0.7737 - 45ms/epoch - 6ms/step
# Epoch 147/500
# 7/7 - 0s - loss: 0.5227 - accuracy: 0.7934 - 46ms/epoch - 7ms/step
# Epoch 148/500
# 7/7 - 0s - loss: 0.5488 - accuracy: 0.7772 - 43ms/epoch - 6ms/step
# Epoch 149/500
# 7/7 - 0s - loss: 0.5416 - accuracy: 0.7808 - 45ms/epoch - 6ms/step
# Epoch 150/500
# 7/7 - 0s - loss: 0.5426 - accuracy: 0.7838 - 44ms/epoch - 6ms/step
# Epoch 151/500
# 7/7 - 0s - loss: 0.5305 - accuracy: 0.7844 - 45ms/epoch - 6ms/step
# Epoch 152/500
# 7/7 - 0s - loss: 0.5444 - accuracy: 0.7790 - 44ms/epoch - 6ms/step
# Epoch 153/500
# 7/7 - 0s - loss: 0.5434 - accuracy: 0.7784 - 43ms/epoch - 6ms/step
# Epoch 154/500
# 7/7 - 0s - loss: 0.5316 - accuracy: 0.7838 - 45ms/epoch - 6ms/step
# Epoch 155/500
# 7/7 - 0s - loss: 0.5268 - accuracy: 0.7898 - 43ms/epoch - 6ms/step
# Epoch 156/500
# 7/7 - 0s - loss: 0.5434 - accuracy: 0.7940 - 45ms/epoch - 6ms/step
# Epoch 157/500
# 7/7 - 0s - loss: 0.5501 - accuracy: 0.7725 - 45ms/epoch - 6ms/step
# Epoch 158/500
# 7/7 - 0s - loss: 0.5253 - accuracy: 0.7898 - 44ms/epoch - 6ms/step
# Epoch 159/500
# 7/7 - 0s - loss: 0.5150 - accuracy: 0.7832 - 44ms/epoch - 6ms/step
# Epoch 160/500
# 7/7 - 0s - loss: 0.5292 - accuracy: 0.7874 - 45ms/epoch - 6ms/step
# Epoch 161/500
# 7/7 - 0s - loss: 0.5283 - accuracy: 0.7832 - 44ms/epoch - 6ms/step
# Epoch 162/500
# 7/7 - 0s - loss: 0.5313 - accuracy: 0.7790 - 43ms/epoch - 6ms/step
# Epoch 163/500
# 7/7 - 0s - loss: 0.5266 - accuracy: 0.7844 - 43ms/epoch - 6ms/step
# Epoch 164/500
# 7/7 - 0s - loss: 0.5242 - accuracy: 0.7922 - 45ms/epoch - 6ms/step
# Epoch 165/500
# 7/7 - 0s - loss: 0.5234 - accuracy: 0.7892 - 45ms/epoch - 6ms/step
# Epoch 166/500
# 7/7 - 0s - loss: 0.5152 - accuracy: 0.7856 - 43ms/epoch - 6ms/step
# Epoch 167/500
# 7/7 - 0s - loss: 0.5203 - accuracy: 0.7970 - 43ms/epoch - 6ms/step
# Epoch 168/500
# 7/7 - 0s - loss: 0.5184 - accuracy: 0.8030 - 46ms/epoch - 7ms/step
# Epoch 169/500
# 7/7 - 0s - loss: 0.5267 - accuracy: 0.8000 - 44ms/epoch - 6ms/step
# Epoch 170/500
# 7/7 - 0s - loss: 0.5112 - accuracy: 0.7880 - 45ms/epoch - 6ms/step
# Epoch 171/500
# 7/7 - 0s - loss: 0.5185 - accuracy: 0.7964 - 45ms/epoch - 6ms/step
# Epoch 172/500
# 7/7 - 0s - loss: 0.5075 - accuracy: 0.7940 - 45ms/epoch - 6ms/step
# Epoch 173/500
# 7/7 - 0s - loss: 0.5241 - accuracy: 0.7940 - 46ms/epoch - 7ms/step
# Epoch 174/500
# 7/7 - 0s - loss: 0.5231 - accuracy: 0.7802 - 43ms/epoch - 6ms/step
# Epoch 175/500
# 7/7 - 0s - loss: 0.5300 - accuracy: 0.7916 - 47ms/epoch - 7ms/step
# Epoch 176/500
# 7/7 - 0s - loss: 0.5156 - accuracy: 0.7970 - 44ms/epoch - 6ms/step
# Epoch 177/500
# 7/7 - 0s - loss: 0.4998 - accuracy: 0.8060 - 44ms/epoch - 6ms/step
# Epoch 178/500
# 7/7 - 0s - loss: 0.5102 - accuracy: 0.7982 - 46ms/epoch - 7ms/step
# Epoch 179/500
# 7/7 - 0s - loss: 0.5000 - accuracy: 0.7994 - 45ms/epoch - 6ms/step
# Epoch 180/500
# 7/7 - 0s - loss: 0.5023 - accuracy: 0.7976 - 45ms/epoch - 6ms/step
# Epoch 181/500
# 7/7 - 0s - loss: 0.5152 - accuracy: 0.8024 - 45ms/epoch - 6ms/step
# Epoch 182/500
# 7/7 - 0s - loss: 0.4982 - accuracy: 0.8024 - 46ms/epoch - 7ms/step
# Epoch 183/500
# 7/7 - 0s - loss: 0.4992 - accuracy: 0.8072 - 46ms/epoch - 7ms/step
# Epoch 184/500
# 7/7 - 0s - loss: 0.4962 - accuracy: 0.8042 - 44ms/epoch - 6ms/step
# Epoch 185/500
# 7/7 - 0s - loss: 0.4980 - accuracy: 0.7892 - 45ms/epoch - 6ms/step
# Epoch 186/500
# 7/7 - 0s - loss: 0.4829 - accuracy: 0.8096 - 46ms/epoch - 7ms/step
# Epoch 187/500
# 7/7 - 0s - loss: 0.5008 - accuracy: 0.7988 - 45ms/epoch - 6ms/step
# Epoch 188/500
# 7/7 - 0s - loss: 0.4994 - accuracy: 0.7964 - 47ms/epoch - 7ms/step
# Epoch 189/500
# 7/7 - 0s - loss: 0.5254 - accuracy: 0.7892 - 47ms/epoch - 7ms/step
# Epoch 190/500
# 7/7 - 0s - loss: 0.5160 - accuracy: 0.7880 - 47ms/epoch - 7ms/step
# Epoch 191/500
# 7/7 - 0s - loss: 0.4949 - accuracy: 0.8144 - 45ms/epoch - 6ms/step
# Epoch 192/500
# 7/7 - 0s - loss: 0.5041 - accuracy: 0.7904 - 47ms/epoch - 7ms/step
# Epoch 193/500
# 7/7 - 0s - loss: 0.4886 - accuracy: 0.7988 - 48ms/epoch - 7ms/step
# Epoch 194/500
# 7/7 - 0s - loss: 0.4805 - accuracy: 0.7988 - 48ms/epoch - 7ms/step
# Epoch 195/500
# 7/7 - 0s - loss: 0.5009 - accuracy: 0.8048 - 46ms/epoch - 7ms/step
# Epoch 196/500
# 7/7 - 0s - loss: 0.5021 - accuracy: 0.8060 - 46ms/epoch - 7ms/step
# Epoch 197/500
# 7/7 - 0s - loss: 0.5042 - accuracy: 0.7988 - 45ms/epoch - 6ms/step
# Epoch 198/500
# 7/7 - 0s - loss: 0.5128 - accuracy: 0.7988 - 47ms/epoch - 7ms/step
# Epoch 199/500
# 7/7 - 0s - loss: 0.4907 - accuracy: 0.8018 - 47ms/epoch - 7ms/step
# Epoch 200/500
# 7/7 - 0s - loss: 0.4961 - accuracy: 0.8072 - 46ms/epoch - 7ms/step
# Epoch 201/500
# 7/7 - 0s - loss: 0.5002 - accuracy: 0.8084 - 46ms/epoch - 7ms/step
# Epoch 202/500
# 7/7 - 0s - loss: 0.4697 - accuracy: 0.8192 - 46ms/epoch - 7ms/step
# Epoch 203/500
# 7/7 - 0s - loss: 0.4840 - accuracy: 0.8132 - 46ms/epoch - 7ms/step
# Epoch 204/500
# 7/7 - 0s - loss: 0.5071 - accuracy: 0.8090 - 46ms/epoch - 7ms/step
# Epoch 205/500
# 7/7 - 0s - loss: 0.4925 - accuracy: 0.8078 - 47ms/epoch - 7ms/step
# Epoch 206/500
# 7/7 - 0s - loss: 0.4757 - accuracy: 0.8126 - 48ms/epoch - 7ms/step
# Epoch 207/500
# 7/7 - 0s - loss: 0.4869 - accuracy: 0.8018 - 50ms/epoch - 7ms/step
# Epoch 208/500
# 7/7 - 0s - loss: 0.4993 - accuracy: 0.8012 - 46ms/epoch - 7ms/step
# Epoch 209/500
# 7/7 - 0s - loss: 0.4930 - accuracy: 0.8012 - 46ms/epoch - 7ms/step
# Epoch 210/500
# 7/7 - 0s - loss: 0.4924 - accuracy: 0.8030 - 47ms/epoch - 7ms/step
# Epoch 211/500
# 7/7 - 0s - loss: 0.4890 - accuracy: 0.8072 - 47ms/epoch - 7ms/step
# Epoch 212/500
# 7/7 - 0s - loss: 0.4845 - accuracy: 0.8036 - 45ms/epoch - 6ms/step
# Epoch 213/500
# 7/7 - 0s - loss: 0.4893 - accuracy: 0.8084 - 45ms/epoch - 6ms/step
# Epoch 214/500
# 7/7 - 0s - loss: 0.4897 - accuracy: 0.8066 - 45ms/epoch - 6ms/step
# Epoch 215/500
# 7/7 - 0s - loss: 0.4754 - accuracy: 0.8132 - 48ms/epoch - 7ms/step
# Epoch 216/500
# 7/7 - 0s - loss: 0.4927 - accuracy: 0.8036 - 46ms/epoch - 7ms/step
# Epoch 217/500
# 7/7 - 0s - loss: 0.4842 - accuracy: 0.8138 - 46ms/epoch - 7ms/step
# Epoch 218/500
# 7/7 - 0s - loss: 0.4709 - accuracy: 0.8114 - 46ms/epoch - 7ms/step
# Epoch 219/500
# 7/7 - 0s - loss: 0.4936 - accuracy: 0.8150 - 46ms/epoch - 7ms/step
# Epoch 220/500
# 7/7 - 0s - loss: 0.4646 - accuracy: 0.8192 - 46ms/epoch - 7ms/step
# Epoch 221/500
# 7/7 - 0s - loss: 0.4731 - accuracy: 0.8132 - 47ms/epoch - 7ms/step
# Epoch 222/500
# 7/7 - 0s - loss: 0.4671 - accuracy: 0.8168 - 46ms/epoch - 7ms/step
# Epoch 223/500
# 7/7 - 0s - loss: 0.4838 - accuracy: 0.8060 - 46ms/epoch - 7ms/step
# Epoch 224/500
# 7/7 - 0s - loss: 0.4634 - accuracy: 0.8156 - 46ms/epoch - 7ms/step
# Epoch 225/500
# 7/7 - 0s - loss: 0.4598 - accuracy: 0.8096 - 47ms/epoch - 7ms/step
# Epoch 226/500
# 7/7 - 0s - loss: 0.4818 - accuracy: 0.8084 - 47ms/epoch - 7ms/step
# Epoch 227/500
# 7/7 - 0s - loss: 0.4897 - accuracy: 0.8096 - 45ms/epoch - 6ms/step
# Epoch 228/500
# 7/7 - 0s - loss: 0.4793 - accuracy: 0.8054 - 47ms/epoch - 7ms/step
# Epoch 229/500
# 7/7 - 0s - loss: 0.4876 - accuracy: 0.8084 - 46ms/epoch - 7ms/step
# Epoch 230/500
# 7/7 - 0s - loss: 0.4771 - accuracy: 0.8180 - 46ms/epoch - 7ms/step
# Epoch 231/500
# 7/7 - 0s - loss: 0.4892 - accuracy: 0.7976 - 45ms/epoch - 6ms/step
# Epoch 232/500
# 7/7 - 0s - loss: 0.4769 - accuracy: 0.8090 - 47ms/epoch - 7ms/step
# Epoch 233/500
# 7/7 - 0s - loss: 0.4711 - accuracy: 0.8287 - 45ms/epoch - 6ms/step
# Epoch 234/500
# 7/7 - 0s - loss: 0.4706 - accuracy: 0.8114 - 49ms/epoch - 7ms/step
# Epoch 235/500
# 7/7 - 0s - loss: 0.4784 - accuracy: 0.8066 - 46ms/epoch - 7ms/step
# Epoch 236/500
# 7/7 - 0s - loss: 0.4765 - accuracy: 0.8048 - 48ms/epoch - 7ms/step
# Epoch 237/500
# 7/7 - 0s - loss: 0.4702 - accuracy: 0.8192 - 47ms/epoch - 7ms/step
# Epoch 238/500
# 7/7 - 0s - loss: 0.4786 - accuracy: 0.8186 - 47ms/epoch - 7ms/step
# Epoch 239/500
# 7/7 - 0s - loss: 0.4728 - accuracy: 0.8186 - 46ms/epoch - 7ms/step
# Epoch 240/500
# 7/7 - 0s - loss: 0.4528 - accuracy: 0.8305 - 45ms/epoch - 6ms/step
# Epoch 241/500
# 7/7 - 0s - loss: 0.4676 - accuracy: 0.8198 - 46ms/epoch - 7ms/step
# Epoch 242/500
# 7/7 - 0s - loss: 0.4824 - accuracy: 0.8114 - 46ms/epoch - 7ms/step
# Epoch 243/500
# 7/7 - 0s - loss: 0.4771 - accuracy: 0.8180 - 47ms/epoch - 7ms/step
# Epoch 244/500
# 7/7 - 0s - loss: 0.4555 - accuracy: 0.8168 - 47ms/epoch - 7ms/step
# Epoch 245/500
# 7/7 - 0s - loss: 0.4735 - accuracy: 0.8168 - 49ms/epoch - 7ms/step
# Epoch 246/500
# 7/7 - 0s - loss: 0.4744 - accuracy: 0.8072 - 48ms/epoch - 7ms/step
# Epoch 247/500
# 7/7 - 0s - loss: 0.4622 - accuracy: 0.8114 - 47ms/epoch - 7ms/step
# Epoch 248/500
# 7/7 - 0s - loss: 0.4723 - accuracy: 0.8132 - 46ms/epoch - 7ms/step
# Epoch 249/500
# 7/7 - 0s - loss: 0.4526 - accuracy: 0.8281 - 49ms/epoch - 7ms/step
# Epoch 250/500
# 7/7 - 0s - loss: 0.4547 - accuracy: 0.8234 - 46ms/epoch - 7ms/step
# Epoch 251/500
# 7/7 - 0s - loss: 0.4495 - accuracy: 0.8281 - 46ms/epoch - 7ms/step
# Epoch 252/500
# 7/7 - 0s - loss: 0.4751 - accuracy: 0.8066 - 46ms/epoch - 7ms/step
# Epoch 253/500
# 7/7 - 0s - loss: 0.4636 - accuracy: 0.8168 - 44ms/epoch - 6ms/step
# Epoch 254/500
# 7/7 - 0s - loss: 0.4650 - accuracy: 0.8234 - 46ms/epoch - 7ms/step
# Epoch 255/500
# 7/7 - 0s - loss: 0.4567 - accuracy: 0.8323 - 46ms/epoch - 7ms/step
# Epoch 256/500
# 7/7 - 0s - loss: 0.4658 - accuracy: 0.8132 - 47ms/epoch - 7ms/step
# Epoch 257/500
# 7/7 - 0s - loss: 0.4580 - accuracy: 0.8186 - 46ms/epoch - 7ms/step
# Epoch 258/500
# 7/7 - 0s - loss: 0.4655 - accuracy: 0.8222 - 47ms/epoch - 7ms/step
# Epoch 259/500
# 7/7 - 0s - loss: 0.4584 - accuracy: 0.8341 - 48ms/epoch - 7ms/step
# Epoch 260/500
# 7/7 - 0s - loss: 0.4635 - accuracy: 0.8156 - 45ms/epoch - 6ms/step
# Epoch 261/500
# 7/7 - 0s - loss: 0.4637 - accuracy: 0.8222 - 46ms/epoch - 7ms/step
# Epoch 262/500
# 7/7 - 0s - loss: 0.4530 - accuracy: 0.8156 - 45ms/epoch - 6ms/step
# Epoch 263/500
# 7/7 - 0s - loss: 0.4591 - accuracy: 0.8257 - 47ms/epoch - 7ms/step
# Epoch 264/500
# 7/7 - 0s - loss: 0.4509 - accuracy: 0.8234 - 48ms/epoch - 7ms/step
# Epoch 265/500
# 7/7 - 0s - loss: 0.4646 - accuracy: 0.8102 - 51ms/epoch - 7ms/step
# Epoch 266/500
# 7/7 - 0s - loss: 0.4529 - accuracy: 0.8102 - 54ms/epoch - 8ms/step
# Epoch 267/500
# 7/7 - 0s - loss: 0.4690 - accuracy: 0.8192 - 54ms/epoch - 8ms/step
# Epoch 268/500
# 7/7 - 0s - loss: 0.4613 - accuracy: 0.8222 - 50ms/epoch - 7ms/step
# Epoch 269/500
# 7/7 - 0s - loss: 0.4411 - accuracy: 0.8222 - 48ms/epoch - 7ms/step
# Epoch 270/500
# 7/7 - 0s - loss: 0.4537 - accuracy: 0.8192 - 50ms/epoch - 7ms/step
# Epoch 271/500
# 7/7 - 0s - loss: 0.4568 - accuracy: 0.8138 - 48ms/epoch - 7ms/step
# Epoch 272/500
# 7/7 - 0s - loss: 0.4403 - accuracy: 0.8329 - 51ms/epoch - 7ms/step
# Epoch 273/500
# 7/7 - 0s - loss: 0.4392 - accuracy: 0.8180 - 50ms/epoch - 7ms/step
# Epoch 274/500
# 7/7 - 0s - loss: 0.4478 - accuracy: 0.8257 - 51ms/epoch - 7ms/step
# Epoch 275/500
# 7/7 - 0s - loss: 0.4532 - accuracy: 0.8180 - 49ms/epoch - 7ms/step
# Epoch 276/500
# 7/7 - 0s - loss: 0.4477 - accuracy: 0.8257 - 51ms/epoch - 7ms/step
# Epoch 277/500
# 7/7 - 0s - loss: 0.4642 - accuracy: 0.8204 - 49ms/epoch - 7ms/step
# Epoch 278/500
# 7/7 - 0s - loss: 0.4424 - accuracy: 0.8246 - 51ms/epoch - 7ms/step
# Epoch 279/500
# 7/7 - 0s - loss: 0.4410 - accuracy: 0.8311 - 51ms/epoch - 7ms/step
# Epoch 280/500
# 7/7 - 0s - loss: 0.4407 - accuracy: 0.8317 - 49ms/epoch - 7ms/step
# Epoch 281/500
# 7/7 - 0s - loss: 0.4327 - accuracy: 0.8323 - 50ms/epoch - 7ms/step
# Epoch 282/500
# 7/7 - 0s - loss: 0.4351 - accuracy: 0.8257 - 50ms/epoch - 7ms/step
# Epoch 283/500
# 7/7 - 0s - loss: 0.4388 - accuracy: 0.8246 - 52ms/epoch - 7ms/step
# Epoch 284/500
# 7/7 - 0s - loss: 0.4530 - accuracy: 0.8192 - 50ms/epoch - 7ms/step
# Epoch 285/500
# 7/7 - 0s - loss: 0.4584 - accuracy: 0.8156 - 53ms/epoch - 8ms/step
# Epoch 286/500
# 7/7 - 0s - loss: 0.4478 - accuracy: 0.8335 - 50ms/epoch - 7ms/step
# Epoch 287/500
# 7/7 - 0s - loss: 0.4242 - accuracy: 0.8359 - 49ms/epoch - 7ms/step
# Epoch 288/500
# 7/7 - 0s - loss: 0.4453 - accuracy: 0.8263 - 49ms/epoch - 7ms/step
# Epoch 289/500
# 7/7 - 0s - loss: 0.4454 - accuracy: 0.8234 - 49ms/epoch - 7ms/step
# Epoch 290/500
# 7/7 - 0s - loss: 0.4168 - accuracy: 0.8371 - 48ms/epoch - 7ms/step
# Epoch 291/500
# 7/7 - 0s - loss: 0.4503 - accuracy: 0.8257 - 46ms/epoch - 7ms/step
# Epoch 292/500
# 7/7 - 0s - loss: 0.4253 - accuracy: 0.8323 - 49ms/epoch - 7ms/step
# Epoch 293/500
# 7/7 - 0s - loss: 0.4263 - accuracy: 0.8389 - 47ms/epoch - 7ms/step
# Epoch 294/500
# 7/7 - 0s - loss: 0.4501 - accuracy: 0.8204 - 49ms/epoch - 7ms/step
# Epoch 295/500
# 7/7 - 0s - loss: 0.4526 - accuracy: 0.8246 - 48ms/epoch - 7ms/step
# Epoch 296/500
# 7/7 - 0s - loss: 0.4321 - accuracy: 0.8293 - 51ms/epoch - 7ms/step
# Epoch 297/500
# 7/7 - 0s - loss: 0.4365 - accuracy: 0.8353 - 49ms/epoch - 7ms/step
# Epoch 298/500
# 7/7 - 0s - loss: 0.4509 - accuracy: 0.8216 - 45ms/epoch - 6ms/step
# Epoch 299/500
# 7/7 - 0s - loss: 0.4229 - accuracy: 0.8413 - 45ms/epoch - 6ms/step
# Epoch 300/500
# 7/7 - 0s - loss: 0.4407 - accuracy: 0.8263 - 48ms/epoch - 7ms/step
# Epoch 301/500
# 7/7 - 0s - loss: 0.4266 - accuracy: 0.8329 - 48ms/epoch - 7ms/step
# Epoch 302/500
# 7/7 - 0s - loss: 0.4267 - accuracy: 0.8323 - 51ms/epoch - 7ms/step
# Epoch 303/500
# 7/7 - 0s - loss: 0.4526 - accuracy: 0.8263 - 49ms/epoch - 7ms/step
# Epoch 304/500
# 7/7 - 0s - loss: 0.4415 - accuracy: 0.8263 - 46ms/epoch - 7ms/step
# Epoch 305/500
# 7/7 - 0s - loss: 0.4370 - accuracy: 0.8311 - 51ms/epoch - 7ms/step
# Epoch 306/500
# 7/7 - 0s - loss: 0.4515 - accuracy: 0.8192 - 48ms/epoch - 7ms/step
# Epoch 307/500
# 7/7 - 0s - loss: 0.4198 - accuracy: 0.8371 - 47ms/epoch - 7ms/step
# Epoch 308/500
# 7/7 - 0s - loss: 0.4372 - accuracy: 0.8299 - 51ms/epoch - 7ms/step
# Epoch 309/500
# 7/7 - 0s - loss: 0.4356 - accuracy: 0.8311 - 53ms/epoch - 8ms/step
# Epoch 310/500
# 7/7 - 0s - loss: 0.4271 - accuracy: 0.8419 - 48ms/epoch - 7ms/step
# Epoch 311/500
# 7/7 - 0s - loss: 0.4213 - accuracy: 0.8359 - 52ms/epoch - 7ms/step
# Epoch 312/500
# 7/7 - 0s - loss: 0.4164 - accuracy: 0.8431 - 48ms/epoch - 7ms/step
# Epoch 313/500
# 7/7 - 0s - loss: 0.4299 - accuracy: 0.8311 - 47ms/epoch - 7ms/step
# Epoch 314/500
# 7/7 - 0s - loss: 0.4177 - accuracy: 0.8353 - 49ms/epoch - 7ms/step
# Epoch 315/500
# 7/7 - 0s - loss: 0.4213 - accuracy: 0.8323 - 50ms/epoch - 7ms/step
# Epoch 316/500
# 7/7 - 0s - loss: 0.4131 - accuracy: 0.8449 - 49ms/epoch - 7ms/step
# Epoch 317/500
# 7/7 - 0s - loss: 0.4222 - accuracy: 0.8443 - 50ms/epoch - 7ms/step
# Epoch 318/500
# 7/7 - 0s - loss: 0.4326 - accuracy: 0.8443 - 48ms/epoch - 7ms/step
# Epoch 319/500
# 7/7 - 0s - loss: 0.4134 - accuracy: 0.8317 - 48ms/epoch - 7ms/step
# Epoch 320/500
# 7/7 - 0s - loss: 0.4167 - accuracy: 0.8521 - 49ms/epoch - 7ms/step
# Epoch 321/500
# 7/7 - 0s - loss: 0.4170 - accuracy: 0.8359 - 47ms/epoch - 7ms/step
# Epoch 322/500
# 7/7 - 0s - loss: 0.4237 - accuracy: 0.8257 - 51ms/epoch - 7ms/step
# Epoch 323/500
# 7/7 - 0s - loss: 0.4365 - accuracy: 0.8246 - 49ms/epoch - 7ms/step
# Epoch 324/500
# 7/7 - 0s - loss: 0.4144 - accuracy: 0.8419 - 48ms/epoch - 7ms/step
# Epoch 325/500
# 7/7 - 0s - loss: 0.4211 - accuracy: 0.8347 - 51ms/epoch - 7ms/step
# Epoch 326/500
# 7/7 - 0s - loss: 0.4349 - accuracy: 0.8269 - 49ms/epoch - 7ms/step
# Epoch 327/500
# 7/7 - 0s - loss: 0.4265 - accuracy: 0.8293 - 49ms/epoch - 7ms/step
# Epoch 328/500
# 7/7 - 0s - loss: 0.4246 - accuracy: 0.8377 - 51ms/epoch - 7ms/step
# Epoch 329/500
# 7/7 - 0s - loss: 0.4240 - accuracy: 0.8383 - 50ms/epoch - 7ms/step
# Epoch 330/500
# 7/7 - 0s - loss: 0.4284 - accuracy: 0.8240 - 48ms/epoch - 7ms/step
# Epoch 331/500
# 7/7 - 0s - loss: 0.4289 - accuracy: 0.8395 - 49ms/epoch - 7ms/step
# Epoch 332/500
# 7/7 - 0s - loss: 0.4262 - accuracy: 0.8335 - 50ms/epoch - 7ms/step
# Epoch 333/500
# 7/7 - 0s - loss: 0.4159 - accuracy: 0.8329 - 48ms/epoch - 7ms/step
# Epoch 334/500
# 7/7 - 0s - loss: 0.4185 - accuracy: 0.8455 - 50ms/epoch - 7ms/step
# Epoch 335/500
# 7/7 - 0s - loss: 0.4183 - accuracy: 0.8281 - 49ms/epoch - 7ms/step
# Epoch 336/500
# 7/7 - 0s - loss: 0.4061 - accuracy: 0.8527 - 50ms/epoch - 7ms/step
# Epoch 337/500
# 7/7 - 0s - loss: 0.4149 - accuracy: 0.8455 - 47ms/epoch - 7ms/step
# Epoch 338/500
# 7/7 - 0s - loss: 0.4217 - accuracy: 0.8401 - 48ms/epoch - 7ms/step
# Epoch 339/500
# 7/7 - 0s - loss: 0.4259 - accuracy: 0.8353 - 49ms/epoch - 7ms/step
# Epoch 340/500
# 7/7 - 0s - loss: 0.4007 - accuracy: 0.8419 - 48ms/epoch - 7ms/step
# Epoch 341/500
# 7/7 - 0s - loss: 0.4248 - accuracy: 0.8389 - 48ms/epoch - 7ms/step
# Epoch 342/500
# 7/7 - 0s - loss: 0.4191 - accuracy: 0.8365 - 49ms/epoch - 7ms/step
# Epoch 343/500
# 7/7 - 0s - loss: 0.4007 - accuracy: 0.8473 - 47ms/epoch - 7ms/step
# Epoch 344/500
# 7/7 - 0s - loss: 0.4257 - accuracy: 0.8335 - 50ms/epoch - 7ms/step
# Epoch 345/500
# 7/7 - 0s - loss: 0.4208 - accuracy: 0.8269 - 50ms/epoch - 7ms/step
# Epoch 346/500
# 7/7 - 0s - loss: 0.4044 - accuracy: 0.8497 - 53ms/epoch - 8ms/step
# Epoch 347/500
# 7/7 - 0s - loss: 0.4239 - accuracy: 0.8365 - 51ms/epoch - 7ms/step
# Epoch 348/500
# 7/7 - 0s - loss: 0.4307 - accuracy: 0.8251 - 47ms/epoch - 7ms/step
# Epoch 349/500
# 7/7 - 0s - loss: 0.4130 - accuracy: 0.8407 - 48ms/epoch - 7ms/step
# Epoch 350/500
# 7/7 - 0s - loss: 0.3979 - accuracy: 0.8533 - 47ms/epoch - 7ms/step
# Epoch 351/500
# 7/7 - 0s - loss: 0.4134 - accuracy: 0.8419 - 50ms/epoch - 7ms/step
# Epoch 352/500
# 7/7 - 0s - loss: 0.4218 - accuracy: 0.8389 - 48ms/epoch - 7ms/step
# Epoch 353/500
# 7/7 - 0s - loss: 0.3978 - accuracy: 0.8413 - 48ms/epoch - 7ms/step
# Epoch 354/500
# 7/7 - 0s - loss: 0.4214 - accuracy: 0.8407 - 52ms/epoch - 7ms/step
# Epoch 355/500
# 7/7 - 0s - loss: 0.3986 - accuracy: 0.8449 - 49ms/epoch - 7ms/step
# Epoch 356/500
# 7/7 - 0s - loss: 0.3918 - accuracy: 0.8593 - 45ms/epoch - 6ms/step
# Epoch 357/500
# 7/7 - 0s - loss: 0.3976 - accuracy: 0.8527 - 44ms/epoch - 6ms/step
# Epoch 358/500
# 7/7 - 0s - loss: 0.4098 - accuracy: 0.8509 - 44ms/epoch - 6ms/step
# Epoch 359/500
# 7/7 - 0s - loss: 0.4009 - accuracy: 0.8479 - 45ms/epoch - 6ms/step
# Epoch 360/500
# 7/7 - 0s - loss: 0.4175 - accuracy: 0.8281 - 45ms/epoch - 6ms/step
# Epoch 361/500
# 7/7 - 0s - loss: 0.4292 - accuracy: 0.8281 - 45ms/epoch - 6ms/step
# Epoch 362/500
# 7/7 - 0s - loss: 0.4194 - accuracy: 0.8389 - 44ms/epoch - 6ms/step
# Epoch 363/500
# 7/7 - 0s - loss: 0.4049 - accuracy: 0.8449 - 47ms/epoch - 7ms/step
# Epoch 364/500
# 7/7 - 0s - loss: 0.4143 - accuracy: 0.8449 - 46ms/epoch - 7ms/step
# Epoch 365/500
# 7/7 - 0s - loss: 0.4038 - accuracy: 0.8425 - 45ms/epoch - 6ms/step
# Epoch 366/500
# 7/7 - 0s - loss: 0.4109 - accuracy: 0.8395 - 44ms/epoch - 6ms/step
# Epoch 367/500
# 7/7 - 0s - loss: 0.4101 - accuracy: 0.8473 - 44ms/epoch - 6ms/step
# Epoch 368/500
# 7/7 - 0s - loss: 0.4094 - accuracy: 0.8401 - 45ms/epoch - 6ms/step
# Epoch 369/500
# 7/7 - 0s - loss: 0.4083 - accuracy: 0.8413 - 46ms/epoch - 7ms/step
# Epoch 370/500
# 7/7 - 0s - loss: 0.4160 - accuracy: 0.8431 - 44ms/epoch - 6ms/step
# Epoch 371/500
# 7/7 - 0s - loss: 0.3973 - accuracy: 0.8395 - 44ms/epoch - 6ms/step
# Epoch 372/500
# 7/7 - 0s - loss: 0.4092 - accuracy: 0.8389 - 44ms/epoch - 6ms/step
# Epoch 373/500
# 7/7 - 0s - loss: 0.3910 - accuracy: 0.8425 - 44ms/epoch - 6ms/step
# Epoch 374/500
# 7/7 - 0s - loss: 0.3992 - accuracy: 0.8449 - 45ms/epoch - 6ms/step
# Epoch 375/500
# 7/7 - 0s - loss: 0.4118 - accuracy: 0.8335 - 46ms/epoch - 7ms/step
# Epoch 376/500
# 7/7 - 0s - loss: 0.3858 - accuracy: 0.8521 - 45ms/epoch - 6ms/step
# Epoch 377/500
# 7/7 - 0s - loss: 0.4028 - accuracy: 0.8437 - 44ms/epoch - 6ms/step
# Epoch 378/500
# 7/7 - 0s - loss: 0.3839 - accuracy: 0.8569 - 44ms/epoch - 6ms/step
# Epoch 379/500
# 7/7 - 0s - loss: 0.3997 - accuracy: 0.8347 - 45ms/epoch - 6ms/step
# Epoch 380/500
# 7/7 - 0s - loss: 0.3967 - accuracy: 0.8551 - 44ms/epoch - 6ms/step
# Epoch 381/500
# 7/7 - 0s - loss: 0.4057 - accuracy: 0.8437 - 45ms/epoch - 6ms/step
# Epoch 382/500
# 7/7 - 0s - loss: 0.3958 - accuracy: 0.8509 - 44ms/epoch - 6ms/step
# Epoch 383/500
# 7/7 - 0s - loss: 0.3975 - accuracy: 0.8419 - 45ms/epoch - 6ms/step
# Epoch 384/500
# 7/7 - 0s - loss: 0.3964 - accuracy: 0.8479 - 45ms/epoch - 6ms/step
# Epoch 385/500
# 7/7 - 0s - loss: 0.3952 - accuracy: 0.8389 - 45ms/epoch - 6ms/step
# Epoch 386/500
# 7/7 - 0s - loss: 0.3820 - accuracy: 0.8521 - 45ms/epoch - 6ms/step
# Epoch 387/500
# 7/7 - 0s - loss: 0.3962 - accuracy: 0.8449 - 46ms/epoch - 7ms/step
# Epoch 388/500
# 7/7 - 0s - loss: 0.4016 - accuracy: 0.8461 - 44ms/epoch - 6ms/step
# Epoch 389/500
# 7/7 - 0s - loss: 0.4251 - accuracy: 0.8365 - 46ms/epoch - 7ms/step
# Epoch 390/500
# 7/7 - 0s - loss: 0.4106 - accuracy: 0.8323 - 45ms/epoch - 6ms/step
# Epoch 391/500
# 7/7 - 0s - loss: 0.4146 - accuracy: 0.8335 - 44ms/epoch - 6ms/step
# Epoch 392/500
# 7/7 - 0s - loss: 0.3966 - accuracy: 0.8509 - 46ms/epoch - 7ms/step
# Epoch 393/500
# 7/7 - 0s - loss: 0.3920 - accuracy: 0.8503 - 46ms/epoch - 7ms/step
# Epoch 394/500
# 7/7 - 0s - loss: 0.3753 - accuracy: 0.8443 - 45ms/epoch - 6ms/step
# Epoch 395/500
# 7/7 - 0s - loss: 0.3998 - accuracy: 0.8443 - 45ms/epoch - 6ms/step
# Epoch 396/500
# 7/7 - 0s - loss: 0.3817 - accuracy: 0.8515 - 47ms/epoch - 7ms/step
# Epoch 397/500
# 7/7 - 0s - loss: 0.3642 - accuracy: 0.8599 - 44ms/epoch - 6ms/step
# Epoch 398/500
# 7/7 - 0s - loss: 0.3979 - accuracy: 0.8491 - 44ms/epoch - 6ms/step
# Epoch 399/500
# 7/7 - 0s - loss: 0.3864 - accuracy: 0.8467 - 44ms/epoch - 6ms/step
# Epoch 400/500
# 7/7 - 0s - loss: 0.3866 - accuracy: 0.8515 - 44ms/epoch - 6ms/step
# Epoch 401/500
# 7/7 - 0s - loss: 0.3852 - accuracy: 0.8563 - 43ms/epoch - 6ms/step
# Epoch 402/500
# 7/7 - 0s - loss: 0.3937 - accuracy: 0.8389 - 47ms/epoch - 7ms/step
# Epoch 403/500
# 7/7 - 0s - loss: 0.3927 - accuracy: 0.8389 - 44ms/epoch - 6ms/step
# Epoch 404/500
# 7/7 - 0s - loss: 0.4055 - accuracy: 0.8425 - 45ms/epoch - 6ms/step
# Epoch 405/500
# 7/7 - 0s - loss: 0.3815 - accuracy: 0.8551 - 45ms/epoch - 6ms/step
# Epoch 406/500
# 7/7 - 0s - loss: 0.3822 - accuracy: 0.8611 - 45ms/epoch - 6ms/step
# Epoch 407/500
# 7/7 - 0s - loss: 0.3734 - accuracy: 0.8587 - 45ms/epoch - 6ms/step
# Epoch 408/500
# 7/7 - 0s - loss: 0.4041 - accuracy: 0.8377 - 45ms/epoch - 6ms/step
# Epoch 409/500
# 7/7 - 0s - loss: 0.3938 - accuracy: 0.8551 - 44ms/epoch - 6ms/step
# Epoch 410/500
# 7/7 - 0s - loss: 0.3932 - accuracy: 0.8599 - 45ms/epoch - 6ms/step
# Epoch 411/500
# 7/7 - 0s - loss: 0.3840 - accuracy: 0.8521 - 45ms/epoch - 6ms/step
# Epoch 412/500
# 7/7 - 0s - loss: 0.3974 - accuracy: 0.8455 - 46ms/epoch - 7ms/step
# Epoch 413/500
# 7/7 - 0s - loss: 0.3815 - accuracy: 0.8659 - 45ms/epoch - 6ms/step
# Epoch 414/500
# 7/7 - 0s - loss: 0.4018 - accuracy: 0.8455 - 46ms/epoch - 7ms/step
# Epoch 415/500
# 7/7 - 0s - loss: 0.3888 - accuracy: 0.8461 - 46ms/epoch - 7ms/step
# Epoch 416/500
# 7/7 - 0s - loss: 0.3898 - accuracy: 0.8437 - 45ms/epoch - 6ms/step
# Epoch 417/500
# 7/7 - 0s - loss: 0.3967 - accuracy: 0.8407 - 45ms/epoch - 6ms/step
# Epoch 418/500
# 7/7 - 0s - loss: 0.3693 - accuracy: 0.8617 - 43ms/epoch - 6ms/step
# Epoch 419/500
# 7/7 - 0s - loss: 0.3799 - accuracy: 0.8521 - 44ms/epoch - 6ms/step
# Epoch 420/500
# 7/7 - 0s - loss: 0.4103 - accuracy: 0.8485 - 44ms/epoch - 6ms/step
# Epoch 421/500
# 7/7 - 0s - loss: 0.3919 - accuracy: 0.8551 - 45ms/epoch - 6ms/step
# Epoch 422/500
# 7/7 - 0s - loss: 0.3831 - accuracy: 0.8587 - 43ms/epoch - 6ms/step
# Epoch 423/500
# 7/7 - 0s - loss: 0.3951 - accuracy: 0.8533 - 45ms/epoch - 6ms/step
# Epoch 424/500
# 7/7 - 0s - loss: 0.3953 - accuracy: 0.8533 - 44ms/epoch - 6ms/step
# Epoch 425/500
# 7/7 - 0s - loss: 0.4051 - accuracy: 0.8449 - 44ms/epoch - 6ms/step
# Epoch 426/500
# 7/7 - 0s - loss: 0.3850 - accuracy: 0.8563 - 45ms/epoch - 6ms/step
# Epoch 427/500
# 7/7 - 0s - loss: 0.3754 - accuracy: 0.8587 - 44ms/epoch - 6ms/step
# Epoch 428/500
# 7/7 - 0s - loss: 0.3752 - accuracy: 0.8581 - 43ms/epoch - 6ms/step
# Epoch 429/500
# 7/7 - 0s - loss: 0.3937 - accuracy: 0.8437 - 46ms/epoch - 7ms/step
# Epoch 430/500
# 7/7 - 0s - loss: 0.3878 - accuracy: 0.8455 - 47ms/epoch - 7ms/step
# Epoch 431/500
# 7/7 - 0s - loss: 0.4034 - accuracy: 0.8461 - 47ms/epoch - 7ms/step
# Epoch 432/500
# 7/7 - 0s - loss: 0.3831 - accuracy: 0.8521 - 46ms/epoch - 7ms/step
# Epoch 433/500
# 7/7 - 0s - loss: 0.3761 - accuracy: 0.8545 - 46ms/epoch - 7ms/step
# Epoch 434/500
# 7/7 - 0s - loss: 0.3623 - accuracy: 0.8617 - 44ms/epoch - 6ms/step
# Epoch 435/500
# 7/7 - 0s - loss: 0.3878 - accuracy: 0.8617 - 46ms/epoch - 7ms/step
# Epoch 436/500
# 7/7 - 0s - loss: 0.3954 - accuracy: 0.8359 - 46ms/epoch - 7ms/step
# Epoch 437/500
# 7/7 - 0s - loss: 0.3958 - accuracy: 0.8479 - 46ms/epoch - 7ms/step
# Epoch 438/500
# 7/7 - 0s - loss: 0.3676 - accuracy: 0.8719 - 45ms/epoch - 6ms/step
# Epoch 439/500
# 7/7 - 0s - loss: 0.3841 - accuracy: 0.8563 - 44ms/epoch - 6ms/step
# Epoch 440/500
# 7/7 - 0s - loss: 0.3827 - accuracy: 0.8611 - 44ms/epoch - 6ms/step
# Epoch 441/500
# 7/7 - 0s - loss: 0.3900 - accuracy: 0.8617 - 44ms/epoch - 6ms/step
# Epoch 442/500
# 7/7 - 0s - loss: 0.3674 - accuracy: 0.8563 - 45ms/epoch - 6ms/step
# Epoch 443/500
# 7/7 - 0s - loss: 0.3786 - accuracy: 0.8611 - 45ms/epoch - 6ms/step
# Epoch 444/500
# 7/7 - 0s - loss: 0.3876 - accuracy: 0.8551 - 47ms/epoch - 7ms/step
# Epoch 445/500
# 7/7 - 0s - loss: 0.3851 - accuracy: 0.8497 - 47ms/epoch - 7ms/step
# Epoch 446/500
# 7/7 - 0s - loss: 0.3816 - accuracy: 0.8551 - 46ms/epoch - 7ms/step
# Epoch 447/500
# 7/7 - 0s - loss: 0.3957 - accuracy: 0.8485 - 49ms/epoch - 7ms/step
# Epoch 448/500
# 7/7 - 0s - loss: 0.3681 - accuracy: 0.8629 - 52ms/epoch - 7ms/step
# Epoch 449/500
# 7/7 - 0s - loss: 0.3640 - accuracy: 0.8563 - 46ms/epoch - 7ms/step
# Epoch 450/500
# 7/7 - 0s - loss: 0.3765 - accuracy: 0.8569 - 46ms/epoch - 7ms/step
# Epoch 451/500
# 7/7 - 0s - loss: 0.3653 - accuracy: 0.8629 - 43ms/epoch - 6ms/step
# Epoch 452/500
# 7/7 - 0s - loss: 0.3767 - accuracy: 0.8569 - 49ms/epoch - 7ms/step
# Epoch 453/500
# 7/7 - 0s - loss: 0.3698 - accuracy: 0.8587 - 45ms/epoch - 6ms/step
# Epoch 454/500
# 7/7 - 0s - loss: 0.3653 - accuracy: 0.8629 - 44ms/epoch - 6ms/step
# Epoch 455/500
# 7/7 - 0s - loss: 0.3824 - accuracy: 0.8551 - 45ms/epoch - 6ms/step
# Epoch 456/500
# 7/7 - 0s - loss: 0.3799 - accuracy: 0.8539 - 45ms/epoch - 6ms/step
# Epoch 457/500
# 7/7 - 0s - loss: 0.3790 - accuracy: 0.8503 - 45ms/epoch - 6ms/step
# Epoch 458/500
# 7/7 - 0s - loss: 0.3830 - accuracy: 0.8545 - 45ms/epoch - 6ms/step
# Epoch 459/500
# 7/7 - 0s - loss: 0.3688 - accuracy: 0.8665 - 44ms/epoch - 6ms/step
# Epoch 460/500
# 7/7 - 0s - loss: 0.3852 - accuracy: 0.8533 - 45ms/epoch - 6ms/step
# Epoch 461/500
# 7/7 - 0s - loss: 0.3511 - accuracy: 0.8683 - 46ms/epoch - 7ms/step
# Epoch 462/500
# 7/7 - 0s - loss: 0.3649 - accuracy: 0.8557 - 45ms/epoch - 6ms/step
# Epoch 463/500
# 7/7 - 0s - loss: 0.3646 - accuracy: 0.8635 - 44ms/epoch - 6ms/step
# Epoch 464/500
# 7/7 - 0s - loss: 0.3841 - accuracy: 0.8527 - 46ms/epoch - 7ms/step
# Epoch 465/500
# 7/7 - 0s - loss: 0.3695 - accuracy: 0.8569 - 44ms/epoch - 6ms/step
# Epoch 466/500
# 7/7 - 0s - loss: 0.3743 - accuracy: 0.8569 - 44ms/epoch - 6ms/step
# Epoch 467/500
# 7/7 - 0s - loss: 0.3513 - accuracy: 0.8647 - 44ms/epoch - 6ms/step
# Epoch 468/500
# 7/7 - 0s - loss: 0.3610 - accuracy: 0.8641 - 46ms/epoch - 7ms/step
# Epoch 469/500
# 7/7 - 0s - loss: 0.3822 - accuracy: 0.8581 - 46ms/epoch - 7ms/step
# Epoch 470/500
# 7/7 - 0s - loss: 0.3769 - accuracy: 0.8557 - 44ms/epoch - 6ms/step
# Epoch 471/500
# 7/7 - 0s - loss: 0.3735 - accuracy: 0.8593 - 44ms/epoch - 6ms/step
# Epoch 472/500
# 7/7 - 0s - loss: 0.3611 - accuracy: 0.8617 - 43ms/epoch - 6ms/step
# Epoch 473/500
# 7/7 - 0s - loss: 0.3697 - accuracy: 0.8587 - 46ms/epoch - 7ms/step
# Epoch 474/500
# 7/7 - 0s - loss: 0.3744 - accuracy: 0.8647 - 44ms/epoch - 6ms/step
# Epoch 475/500
# 7/7 - 0s - loss: 0.3648 - accuracy: 0.8659 - 46ms/epoch - 7ms/step
# Epoch 476/500
# 7/7 - 0s - loss: 0.3656 - accuracy: 0.8683 - 45ms/epoch - 6ms/step
# Epoch 477/500
# 7/7 - 0s - loss: 0.3801 - accuracy: 0.8479 - 46ms/epoch - 7ms/step
# Epoch 478/500
# 7/7 - 0s - loss: 0.3484 - accuracy: 0.8647 - 47ms/epoch - 7ms/step
# Epoch 479/500
# 7/7 - 0s - loss: 0.3568 - accuracy: 0.8659 - 46ms/epoch - 7ms/step
# Epoch 480/500
# 7/7 - 0s - loss: 0.3703 - accuracy: 0.8569 - 43ms/epoch - 6ms/step
# Epoch 481/500
# 7/7 - 0s - loss: 0.3688 - accuracy: 0.8593 - 45ms/epoch - 6ms/step
# Epoch 482/500
# 7/7 - 0s - loss: 0.3799 - accuracy: 0.8587 - 46ms/epoch - 7ms/step
# Epoch 483/500
# 7/7 - 0s - loss: 0.3526 - accuracy: 0.8713 - 44ms/epoch - 6ms/step
# Epoch 484/500
# 7/7 - 0s - loss: 0.3689 - accuracy: 0.8677 - 44ms/epoch - 6ms/step
# Epoch 485/500
# 7/7 - 0s - loss: 0.3681 - accuracy: 0.8557 - 44ms/epoch - 6ms/step
# Epoch 486/500
# 7/7 - 0s - loss: 0.3776 - accuracy: 0.8545 - 45ms/epoch - 6ms/step
# Epoch 487/500
# 7/7 - 0s - loss: 0.3675 - accuracy: 0.8599 - 45ms/epoch - 6ms/step
# Epoch 488/500
# 7/7 - 0s - loss: 0.3669 - accuracy: 0.8581 - 46ms/epoch - 7ms/step
# Epoch 489/500
# 7/7 - 0s - loss: 0.3740 - accuracy: 0.8587 - 44ms/epoch - 6ms/step
# Epoch 490/500
# 7/7 - 0s - loss: 0.3593 - accuracy: 0.8623 - 44ms/epoch - 6ms/step
# Epoch 491/500
# 7/7 - 0s - loss: 0.3634 - accuracy: 0.8635 - 43ms/epoch - 6ms/step
# Epoch 492/500
# 7/7 - 0s - loss: 0.3462 - accuracy: 0.8707 - 43ms/epoch - 6ms/step
# Epoch 493/500
# 7/7 - 0s - loss: 0.3665 - accuracy: 0.8551 - 44ms/epoch - 6ms/step
# Epoch 494/500
# 7/7 - 0s - loss: 0.3651 - accuracy: 0.8623 - 45ms/epoch - 6ms/step
# Epoch 495/500
# 7/7 - 0s - loss: 0.3723 - accuracy: 0.8587 - 43ms/epoch - 6ms/step
# Epoch 496/500
# 7/7 - 0s - loss: 0.3469 - accuracy: 0.8653 - 44ms/epoch - 6ms/step
# Epoch 497/500
# 7/7 - 0s - loss: 0.3764 - accuracy: 0.8623 - 45ms/epoch - 6ms/step
# Epoch 498/500
# 7/7 - 0s - loss: 0.3832 - accuracy: 0.8581 - 44ms/epoch - 6ms/step
# Epoch 499/500
# 7/7 - 0s - loss: 0.3548 - accuracy: 0.8731 - 44ms/epoch - 6ms/step
# Epoch 500/500
# 7/7 - 0s - loss: 0.3567 - accuracy: 0.8671 - 46ms/epoch - 7ms/step
# 14/14 [==============================] - 0s 9ms/step
# 14/14 [==============================] - 0s 2ms/step
# 14/14 [==============================] - 0s 2ms/step
#               precision    recall  f1-score   support
#
#            1     0.8500    0.8815    0.8655       135
#            2     0.7817    0.7986    0.7900       139
#            3     0.0000    0.0000    0.0000         0
#
#    micro avg     0.8156    0.8394    0.8273       274
#    macro avg     0.5439    0.5600    0.5518       274
# weighted avg     0.8153    0.8394    0.8272       274
#
# accuracy_score: 0.7990
#
# ---------------------------------------------------------------------------------
# Train runtime: 0.28569579124450684
# 14/14 [==============================] - 0s 3ms/step - loss: 0.5047 - accuracy: 0.7990
# 14/14 [==============================] - 0s 2ms/step
# Test runtime: 0.5275073051452637
# 14/14 [==============================] - 0s 2ms/step
# 14/14 [==============================] - 0s 3ms/step - loss: 0.5047 - accuracy: 0.7990
# 14/14 [==============================] - 0s 3ms/step - loss: 0.5047 - accuracy: 0.7990
# 14/14 [==============================] - 0s 2ms/step
# 14/14 [==============================] - 0s 3ms/step - loss: 0.5047 - accuracy: 0.7990
# 14/14 [==============================] - 0s 2ms/step
