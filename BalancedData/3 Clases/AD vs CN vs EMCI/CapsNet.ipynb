# %%
pip install tensorflow==2.12.0
# Out:
# Collecting tensorflow==2.12.0
#   Downloading tensorflow-2.12.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (585.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 585.9/585.9 MB 2.5 MB/s eta 0:00:00
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0) (23.5.26)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0) (0.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0) (1.57.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0) (3.9.0)
# Requirement already satisfied: jax>=0.3.15 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0) (0.4.14)
# Collecting keras<2.13,>=2.12.0 (from tensorflow==2.12.0)
#   Downloading keras-2.12.0-py2.py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 46.8 MB/s eta 0:00:00
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0) (16.0.6)
# Requirement already satisfied: numpy<1.24,>=1.22 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0) (1.23.5)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0) (23.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0) (1.16.0)
# Collecting tensorboard<2.13,>=2.12 (from tensorflow==2.12.0)
#   Downloading tensorboard-2.12.3-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 50.2 MB/s eta 0:00:00
# Collecting tensorflow-estimator<2.13,>=2.12.0 (from tensorflow==2.12.0)
#   Downloading tensorflow_estimator-2.12.0-py2.py3-none-any.whl (440 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 440.7/440.7 kB 20.7 MB/s eta 0:00:00
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0) (2.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0) (4.5.0)
# Collecting wrapt<1.15,>=1.11.0 (from tensorflow==2.12.0)
#   Downloading wrapt-1.14.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 10.5 MB/s eta 0:00:00
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0) (0.33.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow==2.12.0) (0.41.2)
# Requirement already satisfied: ml-dtypes>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from jax>=0.3.15->tensorflow==2.12.0) (0.2.0)
# Requirement already satisfied: scipy>=1.7 in /usr/local/lib/python3.10/dist-packages (from jax>=0.3.15->tensorflow==2.12.0) (1.10.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow==2.12.0) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow==2.12.0) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow==2.12.0) (3.4.4)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow==2.12.0) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow==2.12.0) (0.7.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow==2.12.0) (2.3.7)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow==2.12.0) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow==2.12.0) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow==2.12.0) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow==2.12.0) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow==2.12.0) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow==2.12.0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow==2.12.0) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow==2.12.0) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow==2.12.0) (2.1.3)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow==2.12.0) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow==2.12.0) (3.2.2)
# Installing collected packages: wrapt, tensorflow-estimator, keras, tensorboard, tensorflow
#   Attempting uninstall: wrapt
#     Found existing installation: wrapt 1.15.0
#     Uninstalling wrapt-1.15.0:
#       Successfully uninstalled wrapt-1.15.0
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.13.0
#     Uninstalling tensorflow-estimator-2.13.0:
#       Successfully uninstalled tensorflow-estimator-2.13.0
#   Attempting uninstall: keras
#     Found existing installation: keras 2.13.1
#     Uninstalling keras-2.13.1:
#       Successfully uninstalled keras-2.13.1
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.13.0
#     Uninstalling tensorboard-2.13.0:
#       Successfully uninstalled tensorboard-2.13.0
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.13.0
#     Uninstalling tensorflow-2.13.0:
#       Successfully uninstalled tensorflow-2.13.0
# Successfully installed keras-2.12.0 tensorboard-2.12.3 tensorflow-2.12.0 tensorflow-estimator-2.12.0 wrapt-1.14.1

# %%
# libraries
import os
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.base import BaseEstimator
import time

#Visualizers
from yellowbrick.classifier import ClassificationReport
from yellowbrick.classifier import ClassPredictionError
from yellowbrick.classifier import ConfusionMatrix
from yellowbrick.classifier import ROCAUC
from yellowbrick.classifier import PrecisionRecallCurve
import matplotlib.pyplot as plt

#Metrics
#Metrics
from sklearn.metrics import accuracy_score
from sklearn.metrics import cohen_kappa_score
from sklearn.metrics import hamming_loss
from sklearn.metrics import log_loss
from sklearn.metrics import zero_one_loss
from sklearn.metrics import matthews_corrcoef
from sklearn.metrics import precision_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import recall_score
from sklearn.metrics import classification_report



#Classifiers
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn import svm
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.tree import DecisionTreeClassifier

#Neural Network
from tensorflow.keras.layers import Input
from tensorflow.keras.layers import Dense,LSTM
from tensorflow.keras.layers import Conv1D
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
from tensorflow.keras.layers import Lambda, Layer, ReLU
from keras.models import load_model
import tensorflow as tf
from tensorflow.keras.losses import sparse_categorical_crossentropy
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import Conv1D, GlobalMaxPooling1D,Concatenate

import warnings
warnings.filterwarnings('ignore')

# %%
from keras import optimizers

# %%
import tensorflow
import os
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Conv2D, Dense, Input, Reshape, Lambda, Layer, Flatten, BatchNormalization,AveragePooling2D
from tensorflow.keras import backend as K
import matplotlib.pyplot as plt
import numpy as np
from keras.datasets import mnist

from keras import initializers

from keras.utils import to_categorical
from keras.layers.core import Activation

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data_path6 = '/content/drive/MyDrive/AlzheimerCodesDatosPlanos/BasesDeDatos/ADNI/ADNIMERGE.csv'
figures_path = './figures'

# %%
if not os.path.exists(figures_path):
    os.makedirs(figures_path)
if not os.path.exists(figures_path+"/6FP"):
    os.makedirs(figures_path+"/6FP")

# %%
Data = pd.read_csv(data_path6)

# %%
Data
# Out:
#         RID        PTID VISCODE  SITE COLPROT ORIGPROT    EXAMDATE DX_bl  \
# 0         2  011_S_0002      bl    11   ADNI1    ADNI1  2005-09-08    CN
# 1         3  011_S_0003      bl    11   ADNI1    ADNI1  2005-09-12    AD
# 2         3  011_S_0003     m06    11   ADNI1    ADNI1  2006-03-13    AD
# 3         3  011_S_0003     m12    11   ADNI1    ADNI1  2006-09-12    AD
# 4         3  011_S_0003     m24    11   ADNI1    ADNI1  2007-09-12    AD
# ...     ...         ...     ...   ...     ...      ...         ...   ...
# 13910  4384  029_S_4384     m84    29   ADNI3    ADNI2  2019-04-09    CN
# 13911  6703  135_S_6703      bl   135   ADNI3    ADNI3  2019-04-09   NaN
# 13912  6145  014_S_6145     m12    14   ADNI3    ADNI3  2019-04-09    CN
# 13913  6148  014_S_6148     m12    14   ADNI3    ADNI3  2019-04-05   SMC
# 13914  6273  100_S_6273     m12   100   ADNI3    ADNI3  2019-04-05   SMC
#
#         AGE PTGENDER  ...  TAU_bl PTAU_bl   FDG_bl PIB_bl  AV45_bl  Years_bl  \
# 0      74.3     Male  ...     NaN     NaN  1.36665    NaN      NaN  0.000000
# 1      81.3     Male  ...   239.7   22.83  1.08355    NaN      NaN  0.000000
# 2      81.3     Male  ...   239.7   22.83  1.08355    NaN      NaN  0.498289
# 3      81.3     Male  ...   239.7   22.83  1.08355    NaN      NaN  0.999316
# 4      81.3     Male  ...   239.7   22.83  1.08355    NaN      NaN  1.998630
# ...     ...      ...  ...     ...     ...      ...    ...      ...       ...
# 13910  62.3     Male  ...   109.3    9.86  1.12969    NaN  1.06225  7.167690
# 13911  62.7   Female  ...     NaN     NaN      NaN    NaN      NaN  0.000000
# 13912  70.3   Female  ...     NaN     NaN      NaN    NaN      NaN  1.073240
# 13913  81.5   Female  ...     NaN     NaN      NaN    NaN      NaN  1.081450
# 13914  65.8   Female  ...     NaN     NaN      NaN    NaN      NaN  0.980151
#
#        Month_bl  Month   M           update_stamp
# 0       0.00000      0   0  2019-02-14 23:58:27.0
# 1       0.00000      0   0  2019-02-14 23:58:27.0
# 2       5.96721      6   6  2019-02-14 23:58:27.0
# 3      11.96720     12  12  2019-02-14 23:58:27.0
# 4      23.93440     24  24  2019-02-14 23:58:27.0
# ...         ...    ...  ..                    ...
# 13910  85.83610     84  84  2019-04-10 04:36:05.0
# 13911   0.00000      0   0  2019-04-10 04:36:10.0
# 13912  12.85250     12  12  2019-04-11 04:36:24.0
# 13913  12.95080     12  12  2019-04-11 04:36:24.0
# 13914  11.73770     12  12  2019-04-11 04:36:24.0
#
# [13915 rows x 113 columns]

# %%
df=Data[["AGE","PTGENDER","PTEDUCAT", "PTMARRY","APOE4",
        "ADAS11","ADAS13","ADASQ4","MMSE","FAQ", "MOCA",
        "CDRSB","RAVLT_immediate","RAVLT_learning","RAVLT_forgetting",
        "RAVLT_perc_forgetting","LDELTOTAL", "TRABSCOR","mPACCdigit"
        ,"mPACCtrailsB","Ventricles", "Hippocampus","WholeBrain", "Entorhinal",
        "Fusiform", "MidTemp", "ICV","DX_bl"]]

# %%
from sklearn.preprocessing import LabelEncoder

# %%
LabelEncoder_1=LabelEncoder()
df["PTGENDER"]=LabelEncoder_1.fit_transform(df["PTGENDER"])
LabelEncoder_1=LabelEncoder()
df["PTMARRY"]=LabelEncoder_1.fit_transform(df["PTMARRY"])

# %%
df=df.dropna()

# %%
df.drop(df[df['DX_bl']=="SMC"].index,inplace=True)
df.drop(df[df['DX_bl']=="LMCI"].index,inplace=True)

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#       index   AGE  PTGENDER  PTEDUCAT  PTMARRY  APOE4  ADAS11  ADAS13  ADASQ4  \
# 0       126  70.9         0        13        4    0.0     7.0     9.0     2.0
# 1       158  72.9         1        16        2    0.0     8.0    12.0     3.0
# 2       168  70.6         1        16        0    0.0     7.0    10.0     3.0
# 3       239  79.6         1        20        1    0.0     1.0     2.0     1.0
# 4       301  75.2         1        20        1    0.0     4.0     8.0     3.0
# ...     ...   ...       ...       ...      ...    ...     ...     ...     ...
# 1396  13006  61.6         0        16        1    1.0    10.0    16.0     5.0
# 1397  13141  66.5         1        20        1    0.0     2.0     4.0     2.0
# 1398  13144  66.5         1        20        1    0.0     3.0     4.0     1.0
# 1399  13146  66.5         1        20        1    0.0     4.0     5.0     1.0
# 1400  13147  66.5         1        20        1    0.0     5.0     5.0     0.0
#
#       MMSE  ...  mPACCdigit  mPACCtrailsB  Ventricles  Hippocampus  \
# 0     27.0  ...   -3.295350      -3.06194     14066.0       6798.0
# 1     30.0  ...    2.009640       2.92602     37847.0       7766.0
# 2     27.0  ...   -2.839950      -2.59335     32256.0       8091.0
# 3     30.0  ...    6.277940       5.90887     86490.0       7346.0
# 4     30.0  ...    2.806420       1.23442    126505.0       6258.0
# ...    ...  ...         ...           ...         ...          ...
# 1396  25.0  ...   -7.552560      -6.78551     11571.0       6843.0
# 1397  29.0  ...    0.336098       1.11248     50946.0       7841.0
# 1398  30.0  ...    2.294010       3.13929     53954.0       7611.0
# 1399  29.0  ...    1.075870       2.46593     56610.0       7718.0
# 1400  30.0  ...    5.025750       5.42834     58940.0       7302.0
#
#       WholeBrain  Entorhinal  Fusiform  MidTemp        ICV  DX_bl
# 0       842989.0      2816.0   11687.0  13712.0  1248940.0     CN
# 1      1145390.0      3431.0   18241.0  22440.0  1688500.0     CN
# 2      1038300.0      4422.0   19999.0  21636.0  1529950.0     CN
# 3      1050670.0      2951.0   17727.0  22319.0  1839780.0     CN
# 4      1091950.0      4599.0   19659.0  20551.0  1763280.0     CN
# ...          ...         ...       ...      ...        ...    ...
# 1396    920321.0      4029.0   16886.0  18911.0  1197160.0   EMCI
# 1397   1144970.0      3696.0   20021.0  20721.0  1630490.0     CN
# 1398   1084980.0      3586.0   20337.0  21149.0  1633240.0     CN
# 1399   1077610.0      3285.0   20223.0  20725.0  1630500.0     CN
# 1400   1059770.0      3577.0   19839.0  20657.0  1628540.0     CN
#
# [1401 rows x 29 columns]

# %%
for i in range(len(df['DX_bl'])):
  if df['DX_bl'][i]=="EMCI":
    df['DX_bl'][i]=0
  if df['DX_bl'][i]=="CN":
    df['DX_bl'][i]=1

  if df['DX_bl'][i]=="AD":
    df['DX_bl'][i]=2

# %%
df["DX_bl"]=df["DX_bl"].astype("int")

# %%
Labels = df['DX_bl'].values
Features = df.drop(['DX_bl'],axis=1).values


print('Features shape:', Features.shape)
print('Labels shape:', Labels.shape)
# Out:
# Features shape: (1401, 28)
# Labels shape: (1401,)

# %%
df['DX_bl'].value_counts()
# Out:
# 0    696
# 1    583
# 2    122
# Name: DX_bl, dtype: int64

# %%
Labels
# Out:
# array([1, 1, 1, ..., 1, 1, 1])

# %%
LabelDataFrame=pd.DataFrame(Labels)

# %%
LabelDataFrame
# Out:
#       0
# 0     1
# 1     1
# 2     1
# 3     1
# 4     1
# ...  ..
# 1396  0
# 1397  1
# 1398  1
# 1399  1
# 1400  1
#
# [1401 rows x 1 columns]

# %%
#Write function for class-centric metrics
# Classification report
def CR_viz():
    def Class_report(model,classes):
        visualizer = ClassificationReport(model, classes=classes, support=True)
        train_start_time = time.time()
        visualizer.fit(X_train, y_train)  # Fit the visualizer and the model
        print(f'Train runtime: {time.time()-train_start_time}')
        test_start_time = time.time()
        visualizer.score(X_test, y_test)  # Evaluate the model on the test data
        print(f'Test runtime: {time.time()-test_start_time}')
        return visualizer.poof()
    for name, classifier in zip(names, classifiers):
        fig, ax = plt.subplots(nrows=1, ncols=1 )
        Class_report(classifier,classes)
        #fig.savefig(figures_path+"/"+str(len(classes))+"FP/"+name+"_CR.pdf")

#Class Prediction Error
def CPE_viz():
    def CPE(model,classes):
        visualizer = ClassPredictionError(model, classes=classes)
        visualizer.fit(X_train, y_train)  # Fit the visualizer and the model
        visualizer.score(X_test, y_test)  # Evaluate the model on the test data
        return visualizer.poof()
    for name, classifier in zip(names, classifiers):
        fig, ax = plt.subplots(nrows=1, ncols=1 )
        CPE(classifier,classes)
        #fig.savefig(figures_path+"/"+str(len(classes))+"FP/"+name+"_CPE.pdf")

#Confusion matrix
def CM_viz():
    def CM(model,classes):
        visualizer = ConfusionMatrix(model, classes=classes, percent=True)
        visualizer.fit(X_train, y_train)  # Fit the visualizer and the model
        visualizer.score(X_test, y_test)  # Evaluate the model on the test data
        return visualizer.poof()
    for name, classifier in zip(names, classifiers):
        fig, ax = plt.subplots(nrows=1, ncols=1 )
        CM(classifier,classes)
        #fig.savefig(figures_path+"/"+str(len(classes))+"FP/"+name+"_CM.pdf")

#ROC-AUC
def ROC_viz():
    def ROC(model,classes):
        visualizer = ROCAUC(model, classes=classes)
        visualizer.fit(X_train, y_train)  # Fit the visualizer and the model
        visualizer.score(X_test, y_test)  # Evaluate the model on the test data
        return visualizer.poof()
    for name, classifier in zip(names, classifiers):
        fig, ax = plt.subplots(nrows=1, ncols=1 )
        ROC(classifier,classes)
        #fig.savefig(figures_path+"/"+str(len(classes))+"FP/"+name+"_ROC.pdf")

#Precision Recall Curve
def PRC_viz():
    def PRC(model,classes):
        visualizer = PrecisionRecallCurve(model,classes=classes, per_class=True, iso_f1_curves=False,
    fill_area=False, micro=False)
        visualizer.fit(X_train, y_train)  # Fit the visualizer and the model
        visualizer.score(X_test, y_test)  # Evaluate the model on the test data
        return visualizer.poof()
    for name, classifier in zip(names, classifiers):
        fig, ax = plt.subplots(nrows=1, ncols=1 )
        PRC(classifier,classes)
        #fig.savefig(figures_path+"/"+str(len(classes))+"FP/"+name+"_PRC.pdf")

# %%
Labels
# Out:
# array([1, 1, 1, ..., 1, 1, 1])

# %%
from sklearn.utils.multiclass import type_of_target

Labels= Labels[:].astype(int)


from imblearn.over_sampling import SMOTE

sm = SMOTE(random_state=45)

X_sm, y_sm = sm.fit_resample(Features, Labels)

print(f'''Shape of X before SMOTE: {Features.shape}
Shape of X after SMOTE: {X_sm.shape}''')
X_train, X_test, y_train, y_test = train_test_split(X_sm, y_sm, test_size=0.2, random_state=42)

print('Train data shape:', X_train.shape)
print('Train labels shape:', y_train.shape)
print('Test data shape:', X_test.shape)
print('Test labels shape:', y_test.shape)
# Out:
# Shape of X before SMOTE: (1401, 28)
# Shape of X after SMOTE: (2088, 28)
# Train data shape: (1670, 28)
# Train labels shape: (1670,)
# Test data shape: (418, 28)
# Test labels shape: (418,)

# %%
scaler = StandardScaler().fit(X_train)

X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
X_train.shape
# Out:
# (1670, 28)

# %%
X_train=np.expand_dims(X_train, axis=-1)
X_test=np.expand_dims(X_test, axis=-1)

# %%
X_train.shape
# Out:
# (1670, 28, 1)

# %%
#classes
classes = [0, 1, 2]

# %%
y_train[:].dtype
# Out:
# dtype('int64')

# %%
y_test[:].dtype
# Out:
# dtype('int64')

# %%
y_train
# Out:
# array([0, 1, 1, ..., 0, 1, 0])

# %%
#from sklearn.utils.multiclass import type_of_target
#target_type = type_of_target(y_train[:])
#print("Type of target:", target_type)
#y_train= y_train[:].astype(int)
#y_test=y_test[:].astype(int)

# %%
y_train
# Out:
# array([0, 1, 1, ..., 0, 1, 0])

# %%
type_of_target(y_train)
# Out:
# 'multiclass'

# %%
type_of_target(y_test)
# Out:
# 'multiclass'

# %%
# Write function for aggregate metrics
def classifier_metrics():
    def metrics(model):
        #     model=model_name()
        model.fit(X_train, y_train)  # Fit the visualizer and the model
        y_pred = model.predict(X_test)
       # model.save('modeloEpilepsia.h5')
        try:
            y_prob = model.predict_proba(X_test)
            log_metric = log_loss(y_test,y_prob)
        except:
            y_prob = "Not probablistic"
            log_metric = 0
        else:
            y_pred = model.predict(X_test)

        acc_score=accuracy_score(y_test,y_pred)
        clc=classification_report(y_test, y_pred,labels=[1, 2, 3],digits=4)
        print(clc)
        print('accuracy_score: {0:.4f}'.format(acc_score))
    for name in classifiers:
        print (str(name))
        metrics(name)
        print()
        print ("---------------------------------------------------------------------------------")

# %%
from keras.layers import GlobalAveragePooling2D,ReLU
num_clases=3
vec=16
class DigitCapsuleLayer(Layer):
    # creating a layer class in keras
    def __init__(self, **kwargs):
        super(DigitCapsuleLayer, self).__init__(**kwargs)
        self.kernel_initializer = initializers.get('glorot_uniform')

    def build(self, input_shape):
        # initialize weight matrix for each capsule in lower layer
        self.W = self.add_weight(shape = [1,1,num_clases, vec, 256], initializer = self.kernel_initializer, name = 'weights') #:c
        self.built = True

    def call(self, inputs):
        #print(inputs.shape)
        u = tf.reshape(inputs, (-1, 1, 256)) # u.shape: (None, 1152, 8) #:c

        u = tf.expand_dims(u, axis=-2) # u.shape: (None, 1152, 1, 8)
        #print(u.shape)
        u = tf.expand_dims(u, axis=-1) # u.shape: (None, 1152, 1, 8, 1)
        u_hat = tf.matmul(self.W, u) # u_hat.shape: (None, 1152, 10, 16, 1)
        u_hat = tf.squeeze(u_hat, [4]) # u_hat.shape: (None, 1152, 10, 16)
        b = tf.zeros(shape = [K.shape(inputs)[0],2, num_clases, 1])

# routing algorithm with updating coupling coefficient c, using scalar product b/w input capsule and output capsule
        for i in range(3-1):
            c = tf.nn.softmax(b, axis=-2) # c.shape: (None, 1152, 10, 1)
            s = tf.reduce_sum(tf.multiply(c, u_hat), axis=1, keepdims=True) # s.shape: (None, 1, 10, 16)
            v = squash(s) # v.shape: (None, 1, 10, 16)
            agreement = tf.squeeze(tf.matmul(tf.expand_dims(u_hat, axis=-1), tf.expand_dims(v, axis=-1), transpose_a=True), [4]) # agreement.shape: (None, 1152, 10, 1)
            b += agreement

        return v

    def compute_output_shape(self, input_shape):
        return tuple([None, num_clases, vec])

epsilon = 1e-7

def output_layer(inputs):
    return K.sqrt(K.sum(K.square(inputs), -1) + K.epsilon())

def squash(inputs):
    # take norm of input vectors
    squared_norm = tf.keras.backend.sum(tf.keras.backend.square(inputs), axis = -1, keepdims = True)

    # use the formula for non-linear function to return squashed output
    return ((squared_norm/(1+squared_norm))/(K.sqrt(squared_norm+K.epsilon())))*inputs

def safe_norm(v, axis=-1, epsilon=1e-7):
    v_ = tf.reduce_sum(tf.square(v), axis = axis, keepdims=True)
    return tf.sqrt(v_ + epsilon)

# %%
class KerasBatchClassifier(KerasClassifier, BaseEstimator):
    def __init__(self, model, **kwargs):
        super().__init__(model)
        self.fit_kwargs = kwargs
        self._estimator_type = 'classifier'

    def fit(self, x, y, *args, **kwargs):
        y = np.array(y)
        if len(y.shape) == 2 and y.shape[1] > 1:
          self.classes_ = np.arange(y.shape[1])
        elif (len(y.shape) == 2 and y.shape[1] == 1) or len(y.shape) == 1:
          self.classes_ = np.unique(y)
          y = np.searchsorted(self.classes_, y)
        else:
          raise ValueError('Invalid shape for y: ' + str(y.shape))
        self.n_classes_ = len(self.classes_)
        return super(KerasClassifier, self).fit(x, y, **self.fit_kwargs)


# RED NEURONAL
def FullyConnected():


  inputs = Input(shape=(X_train.shape[1],1), name="input_1")


  Layer_1=tf.keras.layers.Conv1D(8,3,activation="selu",padding="same")(inputs)


#16

  Layer_1=tf.keras.layers.Conv1D(16,3,activation="selu",padding="same")(Layer_1)

#32

  Layer_1=tf.keras.layers.Conv1D(32,3,activation="selu",padding="same")(Layer_1)
  Pool_1=tf.keras.layers.MaxPool1D(2)(Layer_1)
  Pool_1=tf.keras.layers.Dropout(rate=0.5)(Pool_1)

#64

  Layer_1=tf.keras.layers.Conv1D(64,3,activation="selu",padding="same")(Pool_1)
  Pool_1=tf.keras.layers.MaxPool1D(2)(Layer_1)
  Pool_1=tf.keras.layers.Dropout(rate=0.5)(Pool_1)

#128

  Layer_1=tf.keras.layers.Conv1D(128,3,activation="selu",padding="same")(Pool_1)
  Pool_1=tf.keras.layers.MaxPool1D(2)(Layer_1)
  Pool_1=tf.keras.layers.Dropout(rate=0.5)(Pool_1)

#256

  Layer_1=tf.keras.layers.Conv1D(256,3,activation="selu",padding="same")(Pool_1)
  Pool_1=tf.keras.layers.MaxPool1D(2)(Layer_1)
  Pool_1=tf.keras.layers.Dropout(rate=0.5)(Pool_1)

  squashed_output = tf.keras.layers.Lambda(squash)(Pool_1)
  digit_caps = DigitCapsuleLayer()(squashed_output)
  Acont= safe_norm(digit_caps)
  mast = tf.reshape(Acont, (-1,Acont.shape[2],Acont.shape[3]))
  outputs = tf.keras.layers.Lambda(output_layer)(mast)
  model = Model(inputs = inputs, outputs = outputs)

  optimizer=Adam(learning_rate=0.001)
  model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
  return model

# %%
classifiers=[KerasBatchClassifier(FullyConnected, epochs=500, batch_size=256, verbose=2)]
names = ['FNN']
classifier_metrics()
visualization =[CR_viz(),CPE_viz(),CM_viz(),ROC_viz()]
# Out:
# KerasBatchClassifier(build_fn=<function FullyConnected at 0x7f60acf684c0>)
# Epoch 1/500
# 7/7 - 15s - loss: 1.0887 - accuracy: 0.4030 - 15s/epoch - 2s/step
# Epoch 2/500
# 7/7 - 0s - loss: 0.9302 - accuracy: 0.5569 - 55ms/epoch - 8ms/step
# Epoch 3/500
# 7/7 - 0s - loss: 0.7863 - accuracy: 0.6305 - 50ms/epoch - 7ms/step
# Epoch 4/500
# 7/7 - 0s - loss: 0.7042 - accuracy: 0.6437 - 60ms/epoch - 9ms/step
# Epoch 5/500
# 7/7 - 0s - loss: 0.6729 - accuracy: 0.6623 - 52ms/epoch - 7ms/step
# Epoch 6/500
# 7/7 - 0s - loss: 0.6505 - accuracy: 0.6521 - 50ms/epoch - 7ms/step
# Epoch 7/500
# 7/7 - 0s - loss: 0.6369 - accuracy: 0.6820 - 50ms/epoch - 7ms/step
# Epoch 8/500
# 7/7 - 0s - loss: 0.6238 - accuracy: 0.6862 - 47ms/epoch - 7ms/step
# Epoch 9/500
# 7/7 - 0s - loss: 0.6025 - accuracy: 0.7257 - 48ms/epoch - 7ms/step
# Epoch 10/500
# 7/7 - 0s - loss: 0.5929 - accuracy: 0.7132 - 47ms/epoch - 7ms/step
# Epoch 11/500
# 7/7 - 0s - loss: 0.5790 - accuracy: 0.7299 - 45ms/epoch - 6ms/step
# Epoch 12/500
# 7/7 - 0s - loss: 0.5700 - accuracy: 0.7419 - 51ms/epoch - 7ms/step
# Epoch 13/500
# 7/7 - 0s - loss: 0.5571 - accuracy: 0.7473 - 45ms/epoch - 6ms/step
# Epoch 14/500
# 7/7 - 0s - loss: 0.5368 - accuracy: 0.7449 - 51ms/epoch - 7ms/step
# Epoch 15/500
# 7/7 - 0s - loss: 0.5355 - accuracy: 0.7479 - 46ms/epoch - 7ms/step
# Epoch 16/500
# 7/7 - 0s - loss: 0.5297 - accuracy: 0.7479 - 45ms/epoch - 6ms/step
# Epoch 17/500
# 7/7 - 0s - loss: 0.5158 - accuracy: 0.7629 - 45ms/epoch - 6ms/step
# Epoch 18/500
# 7/7 - 0s - loss: 0.5055 - accuracy: 0.7743 - 47ms/epoch - 7ms/step
# Epoch 19/500
# 7/7 - 0s - loss: 0.5080 - accuracy: 0.7766 - 48ms/epoch - 7ms/step
# Epoch 20/500
# 7/7 - 0s - loss: 0.5064 - accuracy: 0.7707 - 49ms/epoch - 7ms/step
# Epoch 21/500
# 7/7 - 0s - loss: 0.4926 - accuracy: 0.7838 - 50ms/epoch - 7ms/step
# Epoch 22/500
# 7/7 - 0s - loss: 0.4767 - accuracy: 0.7910 - 49ms/epoch - 7ms/step
# Epoch 23/500
# 7/7 - 0s - loss: 0.4893 - accuracy: 0.7766 - 65ms/epoch - 9ms/step
# Epoch 24/500
# 7/7 - 0s - loss: 0.4796 - accuracy: 0.7880 - 49ms/epoch - 7ms/step
# Epoch 25/500
# 7/7 - 0s - loss: 0.4375 - accuracy: 0.8096 - 48ms/epoch - 7ms/step
# Epoch 26/500
# 7/7 - 0s - loss: 0.4597 - accuracy: 0.7886 - 50ms/epoch - 7ms/step
# Epoch 27/500
# 7/7 - 0s - loss: 0.4376 - accuracy: 0.8042 - 47ms/epoch - 7ms/step
# Epoch 28/500
# 7/7 - 0s - loss: 0.4493 - accuracy: 0.8000 - 51ms/epoch - 7ms/step
# Epoch 29/500
# 7/7 - 0s - loss: 0.4352 - accuracy: 0.8198 - 49ms/epoch - 7ms/step
# Epoch 30/500
# 7/7 - 0s - loss: 0.4420 - accuracy: 0.8072 - 48ms/epoch - 7ms/step
# Epoch 31/500
# 7/7 - 0s - loss: 0.4269 - accuracy: 0.8162 - 48ms/epoch - 7ms/step
# Epoch 32/500
# 7/7 - 0s - loss: 0.4213 - accuracy: 0.8257 - 46ms/epoch - 7ms/step
# Epoch 33/500
# 7/7 - 0s - loss: 0.4157 - accuracy: 0.8329 - 56ms/epoch - 8ms/step
# Epoch 34/500
# 7/7 - 0s - loss: 0.4240 - accuracy: 0.8096 - 49ms/epoch - 7ms/step
# Epoch 35/500
# 7/7 - 0s - loss: 0.4149 - accuracy: 0.8234 - 46ms/epoch - 7ms/step
# Epoch 36/500
# 7/7 - 0s - loss: 0.4128 - accuracy: 0.8263 - 47ms/epoch - 7ms/step
# Epoch 37/500
# 7/7 - 0s - loss: 0.4178 - accuracy: 0.8186 - 46ms/epoch - 7ms/step
# Epoch 38/500
# 7/7 - 0s - loss: 0.4047 - accuracy: 0.8311 - 46ms/epoch - 7ms/step
# Epoch 39/500
# 7/7 - 0s - loss: 0.4034 - accuracy: 0.8257 - 53ms/epoch - 8ms/step
# Epoch 40/500
# 7/7 - 0s - loss: 0.3927 - accuracy: 0.8347 - 46ms/epoch - 7ms/step
# Epoch 41/500
# 7/7 - 0s - loss: 0.3910 - accuracy: 0.8293 - 46ms/epoch - 7ms/step
# Epoch 42/500
# 7/7 - 0s - loss: 0.3868 - accuracy: 0.8317 - 55ms/epoch - 8ms/step
# Epoch 43/500
# 7/7 - 0s - loss: 0.3757 - accuracy: 0.8467 - 55ms/epoch - 8ms/step
# Epoch 44/500
# 7/7 - 0s - loss: 0.3719 - accuracy: 0.8455 - 46ms/epoch - 7ms/step
# Epoch 45/500
# 7/7 - 0s - loss: 0.3691 - accuracy: 0.8389 - 46ms/epoch - 7ms/step
# Epoch 46/500
# 7/7 - 0s - loss: 0.3837 - accuracy: 0.8377 - 49ms/epoch - 7ms/step
# Epoch 47/500
# 7/7 - 0s - loss: 0.3810 - accuracy: 0.8413 - 55ms/epoch - 8ms/step
# Epoch 48/500
# 7/7 - 0s - loss: 0.3708 - accuracy: 0.8437 - 46ms/epoch - 7ms/step
# Epoch 49/500
# 7/7 - 0s - loss: 0.3730 - accuracy: 0.8365 - 46ms/epoch - 7ms/step
# Epoch 50/500
# 7/7 - 0s - loss: 0.3616 - accuracy: 0.8527 - 47ms/epoch - 7ms/step
# Epoch 51/500
# 7/7 - 0s - loss: 0.3755 - accuracy: 0.8419 - 48ms/epoch - 7ms/step
# Epoch 52/500
# 7/7 - 0s - loss: 0.3676 - accuracy: 0.8425 - 50ms/epoch - 7ms/step
# Epoch 53/500
# 7/7 - 0s - loss: 0.3608 - accuracy: 0.8419 - 53ms/epoch - 8ms/step
# Epoch 54/500
# 7/7 - 0s - loss: 0.3648 - accuracy: 0.8491 - 48ms/epoch - 7ms/step
# Epoch 55/500
# 7/7 - 0s - loss: 0.3549 - accuracy: 0.8545 - 47ms/epoch - 7ms/step
# Epoch 56/500
# 7/7 - 0s - loss: 0.3609 - accuracy: 0.8473 - 47ms/epoch - 7ms/step
# Epoch 57/500
# 7/7 - 0s - loss: 0.3464 - accuracy: 0.8575 - 51ms/epoch - 7ms/step
# Epoch 58/500
# 7/7 - 0s - loss: 0.3485 - accuracy: 0.8581 - 49ms/epoch - 7ms/step
# Epoch 59/500
# 7/7 - 0s - loss: 0.3519 - accuracy: 0.8593 - 53ms/epoch - 8ms/step
# Epoch 60/500
# 7/7 - 0s - loss: 0.3391 - accuracy: 0.8569 - 52ms/epoch - 7ms/step
# Epoch 61/500
# 7/7 - 0s - loss: 0.3672 - accuracy: 0.8413 - 48ms/epoch - 7ms/step
# Epoch 62/500
# 7/7 - 0s - loss: 0.3360 - accuracy: 0.8563 - 48ms/epoch - 7ms/step
# Epoch 63/500
# 7/7 - 0s - loss: 0.3442 - accuracy: 0.8521 - 56ms/epoch - 8ms/step
# Epoch 64/500
# 7/7 - 0s - loss: 0.3423 - accuracy: 0.8569 - 46ms/epoch - 7ms/step
# Epoch 65/500
# 7/7 - 0s - loss: 0.3278 - accuracy: 0.8617 - 53ms/epoch - 8ms/step
# Epoch 66/500
# 7/7 - 0s - loss: 0.3275 - accuracy: 0.8683 - 47ms/epoch - 7ms/step
# Epoch 67/500
# 7/7 - 0s - loss: 0.3417 - accuracy: 0.8575 - 55ms/epoch - 8ms/step
# Epoch 68/500
# 7/7 - 0s - loss: 0.3192 - accuracy: 0.8743 - 46ms/epoch - 7ms/step
# Epoch 69/500
# 7/7 - 0s - loss: 0.3355 - accuracy: 0.8569 - 51ms/epoch - 7ms/step
# Epoch 70/500
# 7/7 - 0s - loss: 0.3213 - accuracy: 0.8725 - 68ms/epoch - 10ms/step
# Epoch 71/500
# 7/7 - 0s - loss: 0.3209 - accuracy: 0.8707 - 69ms/epoch - 10ms/step
# Epoch 72/500
# 7/7 - 0s - loss: 0.3230 - accuracy: 0.8713 - 72ms/epoch - 10ms/step
# Epoch 73/500
# 7/7 - 0s - loss: 0.3283 - accuracy: 0.8587 - 70ms/epoch - 10ms/step
# Epoch 74/500
# 7/7 - 0s - loss: 0.3204 - accuracy: 0.8695 - 69ms/epoch - 10ms/step
# Epoch 75/500
# 7/7 - 0s - loss: 0.3284 - accuracy: 0.8665 - 80ms/epoch - 11ms/step
# Epoch 76/500
# 7/7 - 0s - loss: 0.3202 - accuracy: 0.8671 - 81ms/epoch - 12ms/step
# Epoch 77/500
# 7/7 - 0s - loss: 0.3217 - accuracy: 0.8695 - 66ms/epoch - 9ms/step
# Epoch 78/500
# 7/7 - 0s - loss: 0.3071 - accuracy: 0.8778 - 66ms/epoch - 9ms/step
# Epoch 79/500
# 7/7 - 0s - loss: 0.3162 - accuracy: 0.8701 - 69ms/epoch - 10ms/step
# Epoch 80/500
# 7/7 - 0s - loss: 0.3032 - accuracy: 0.8790 - 71ms/epoch - 10ms/step
# Epoch 81/500
# 7/7 - 0s - loss: 0.3052 - accuracy: 0.8701 - 67ms/epoch - 10ms/step
# Epoch 82/500
# 7/7 - 0s - loss: 0.3023 - accuracy: 0.8826 - 69ms/epoch - 10ms/step
# Epoch 83/500
# 7/7 - 0s - loss: 0.2982 - accuracy: 0.8838 - 81ms/epoch - 12ms/step
# Epoch 84/500
# 7/7 - 0s - loss: 0.2999 - accuracy: 0.8802 - 67ms/epoch - 10ms/step
# Epoch 85/500
# 7/7 - 0s - loss: 0.2947 - accuracy: 0.8838 - 67ms/epoch - 10ms/step
# Epoch 86/500
# 7/7 - 0s - loss: 0.3046 - accuracy: 0.8772 - 67ms/epoch - 10ms/step
# Epoch 87/500
# 7/7 - 0s - loss: 0.3014 - accuracy: 0.8778 - 73ms/epoch - 10ms/step
# Epoch 88/500
# 7/7 - 0s - loss: 0.2933 - accuracy: 0.8862 - 69ms/epoch - 10ms/step
# Epoch 89/500
# 7/7 - 0s - loss: 0.3130 - accuracy: 0.8677 - 71ms/epoch - 10ms/step
# Epoch 90/500
# 7/7 - 0s - loss: 0.2817 - accuracy: 0.8814 - 76ms/epoch - 11ms/step
# Epoch 91/500
# 7/7 - 0s - loss: 0.2925 - accuracy: 0.8737 - 72ms/epoch - 10ms/step
# Epoch 92/500
# 7/7 - 0s - loss: 0.2792 - accuracy: 0.8886 - 71ms/epoch - 10ms/step
# Epoch 93/500
# 7/7 - 0s - loss: 0.2782 - accuracy: 0.8922 - 65ms/epoch - 9ms/step
# Epoch 94/500
# 7/7 - 0s - loss: 0.3012 - accuracy: 0.8772 - 65ms/epoch - 9ms/step
# Epoch 95/500
# 7/7 - 0s - loss: 0.2924 - accuracy: 0.8874 - 66ms/epoch - 9ms/step
# Epoch 96/500
# 7/7 - 0s - loss: 0.2905 - accuracy: 0.8856 - 67ms/epoch - 10ms/step
# Epoch 97/500
# 7/7 - 0s - loss: 0.2942 - accuracy: 0.8802 - 63ms/epoch - 9ms/step
# Epoch 98/500
# 7/7 - 0s - loss: 0.2880 - accuracy: 0.8862 - 64ms/epoch - 9ms/step
# Epoch 99/500
# 7/7 - 0s - loss: 0.2822 - accuracy: 0.8826 - 68ms/epoch - 10ms/step
# Epoch 100/500
# 7/7 - 0s - loss: 0.2876 - accuracy: 0.8892 - 83ms/epoch - 12ms/step
# Epoch 101/500
# 7/7 - 0s - loss: 0.2765 - accuracy: 0.8982 - 66ms/epoch - 9ms/step
# Epoch 102/500
# 7/7 - 0s - loss: 0.2947 - accuracy: 0.8814 - 67ms/epoch - 10ms/step
# Epoch 103/500
# 7/7 - 0s - loss: 0.2749 - accuracy: 0.8952 - 65ms/epoch - 9ms/step
# Epoch 104/500
# 7/7 - 0s - loss: 0.2899 - accuracy: 0.8826 - 69ms/epoch - 10ms/step
# Epoch 105/500
# 7/7 - 0s - loss: 0.2818 - accuracy: 0.8844 - 63ms/epoch - 9ms/step
# Epoch 106/500
# 7/7 - 0s - loss: 0.2914 - accuracy: 0.8922 - 68ms/epoch - 10ms/step
# Epoch 107/500
# 7/7 - 0s - loss: 0.2688 - accuracy: 0.8862 - 73ms/epoch - 10ms/step
# Epoch 108/500
# 7/7 - 0s - loss: 0.2578 - accuracy: 0.8988 - 71ms/epoch - 10ms/step
# Epoch 109/500
# 7/7 - 0s - loss: 0.2772 - accuracy: 0.8874 - 68ms/epoch - 10ms/step
# Epoch 110/500
# 7/7 - 0s - loss: 0.2898 - accuracy: 0.8784 - 71ms/epoch - 10ms/step
# Epoch 111/500
# 7/7 - 0s - loss: 0.2755 - accuracy: 0.8808 - 71ms/epoch - 10ms/step
# Epoch 112/500
# 7/7 - 0s - loss: 0.2744 - accuracy: 0.8880 - 72ms/epoch - 10ms/step
# Epoch 113/500
# 7/7 - 0s - loss: 0.2754 - accuracy: 0.8838 - 72ms/epoch - 10ms/step
# Epoch 114/500
# 7/7 - 0s - loss: 0.2669 - accuracy: 0.8952 - 68ms/epoch - 10ms/step
# Epoch 115/500
# 7/7 - 0s - loss: 0.2700 - accuracy: 0.9018 - 68ms/epoch - 10ms/step
# Epoch 116/500
# 7/7 - 0s - loss: 0.2746 - accuracy: 0.8958 - 84ms/epoch - 12ms/step
# Epoch 117/500
# 7/7 - 0s - loss: 0.2712 - accuracy: 0.8922 - 82ms/epoch - 12ms/step
# Epoch 118/500
# 7/7 - 0s - loss: 0.2650 - accuracy: 0.8886 - 77ms/epoch - 11ms/step
# Epoch 119/500
# 7/7 - 0s - loss: 0.2549 - accuracy: 0.9024 - 72ms/epoch - 10ms/step
# Epoch 120/500
# 7/7 - 0s - loss: 0.2589 - accuracy: 0.8994 - 77ms/epoch - 11ms/step
# Epoch 121/500
# 7/7 - 0s - loss: 0.2706 - accuracy: 0.8904 - 74ms/epoch - 11ms/step
# Epoch 122/500
# 7/7 - 0s - loss: 0.2528 - accuracy: 0.8994 - 69ms/epoch - 10ms/step
# Epoch 123/500
# 7/7 - 0s - loss: 0.2785 - accuracy: 0.8910 - 70ms/epoch - 10ms/step
# Epoch 124/500
# 7/7 - 0s - loss: 0.2695 - accuracy: 0.8928 - 70ms/epoch - 10ms/step
# Epoch 125/500
# 7/7 - 0s - loss: 0.2533 - accuracy: 0.9018 - 74ms/epoch - 11ms/step
# Epoch 126/500
# 7/7 - 0s - loss: 0.2704 - accuracy: 0.8964 - 76ms/epoch - 11ms/step
# Epoch 127/500
# 7/7 - 0s - loss: 0.2632 - accuracy: 0.8922 - 79ms/epoch - 11ms/step
# Epoch 128/500
# 7/7 - 0s - loss: 0.2620 - accuracy: 0.8994 - 73ms/epoch - 10ms/step
# Epoch 129/500
# 7/7 - 0s - loss: 0.2744 - accuracy: 0.8856 - 65ms/epoch - 9ms/step
# Epoch 130/500
# 7/7 - 0s - loss: 0.2643 - accuracy: 0.8982 - 84ms/epoch - 12ms/step
# Epoch 131/500
# 7/7 - 0s - loss: 0.2657 - accuracy: 0.8958 - 81ms/epoch - 12ms/step
# Epoch 132/500
# 7/7 - 0s - loss: 0.2670 - accuracy: 0.8946 - 76ms/epoch - 11ms/step
# Epoch 133/500
# 7/7 - 0s - loss: 0.2568 - accuracy: 0.9006 - 72ms/epoch - 10ms/step
# Epoch 134/500
# 7/7 - 0s - loss: 0.2570 - accuracy: 0.8994 - 76ms/epoch - 11ms/step
# Epoch 135/500
# 7/7 - 0s - loss: 0.2480 - accuracy: 0.8988 - 75ms/epoch - 11ms/step
# Epoch 136/500
# 7/7 - 0s - loss: 0.2567 - accuracy: 0.8940 - 78ms/epoch - 11ms/step
# Epoch 137/500
# 7/7 - 0s - loss: 0.2502 - accuracy: 0.8964 - 78ms/epoch - 11ms/step
# Epoch 138/500
# 7/7 - 0s - loss: 0.2569 - accuracy: 0.8952 - 79ms/epoch - 11ms/step
# Epoch 139/500
# 7/7 - 0s - loss: 0.2514 - accuracy: 0.9018 - 85ms/epoch - 12ms/step
# Epoch 140/500
# 7/7 - 0s - loss: 0.2447 - accuracy: 0.8994 - 76ms/epoch - 11ms/step
# Epoch 141/500
# 7/7 - 0s - loss: 0.2667 - accuracy: 0.8940 - 76ms/epoch - 11ms/step
# Epoch 142/500
# 7/7 - 0s - loss: 0.2395 - accuracy: 0.9048 - 76ms/epoch - 11ms/step
# Epoch 143/500
# 7/7 - 0s - loss: 0.2608 - accuracy: 0.8970 - 73ms/epoch - 10ms/step
# Epoch 144/500
# 7/7 - 0s - loss: 0.2415 - accuracy: 0.9096 - 73ms/epoch - 10ms/step
# Epoch 145/500
# 7/7 - 0s - loss: 0.2506 - accuracy: 0.9072 - 76ms/epoch - 11ms/step
# Epoch 146/500
# 7/7 - 0s - loss: 0.2627 - accuracy: 0.9006 - 74ms/epoch - 11ms/step
# Epoch 147/500
# 7/7 - 0s - loss: 0.2439 - accuracy: 0.9012 - 72ms/epoch - 10ms/step
# Epoch 148/500
# 7/7 - 0s - loss: 0.2502 - accuracy: 0.9012 - 72ms/epoch - 10ms/step
# Epoch 149/500
# 7/7 - 0s - loss: 0.2472 - accuracy: 0.9030 - 72ms/epoch - 10ms/step
# Epoch 150/500
# 7/7 - 0s - loss: 0.2618 - accuracy: 0.8898 - 75ms/epoch - 11ms/step
# Epoch 151/500
# 7/7 - 0s - loss: 0.2475 - accuracy: 0.8952 - 74ms/epoch - 11ms/step
# Epoch 152/500
# 7/7 - 0s - loss: 0.2525 - accuracy: 0.8994 - 74ms/epoch - 11ms/step
# Epoch 153/500
# 7/7 - 0s - loss: 0.2352 - accuracy: 0.9090 - 73ms/epoch - 10ms/step
# Epoch 154/500
# 7/7 - 0s - loss: 0.2526 - accuracy: 0.9000 - 78ms/epoch - 11ms/step
# Epoch 155/500
# 7/7 - 0s - loss: 0.2431 - accuracy: 0.9108 - 74ms/epoch - 11ms/step
# Epoch 156/500
# 7/7 - 0s - loss: 0.2514 - accuracy: 0.8988 - 76ms/epoch - 11ms/step
# Epoch 157/500
# 7/7 - 0s - loss: 0.2403 - accuracy: 0.9012 - 55ms/epoch - 8ms/step
# Epoch 158/500
# 7/7 - 0s - loss: 0.2507 - accuracy: 0.9102 - 52ms/epoch - 7ms/step
# Epoch 159/500
# 7/7 - 0s - loss: 0.2455 - accuracy: 0.9024 - 50ms/epoch - 7ms/step
# Epoch 160/500
# 7/7 - 0s - loss: 0.2423 - accuracy: 0.9030 - 49ms/epoch - 7ms/step
# Epoch 161/500
# 7/7 - 0s - loss: 0.2367 - accuracy: 0.9042 - 46ms/epoch - 7ms/step
# Epoch 162/500
# 7/7 - 0s - loss: 0.2366 - accuracy: 0.9096 - 47ms/epoch - 7ms/step
# Epoch 163/500
# 7/7 - 0s - loss: 0.2399 - accuracy: 0.9072 - 49ms/epoch - 7ms/step
# Epoch 164/500
# 7/7 - 0s - loss: 0.2357 - accuracy: 0.9030 - 47ms/epoch - 7ms/step
# Epoch 165/500
# 7/7 - 0s - loss: 0.2353 - accuracy: 0.9120 - 47ms/epoch - 7ms/step
# Epoch 166/500
# 7/7 - 0s - loss: 0.2270 - accuracy: 0.9192 - 46ms/epoch - 7ms/step
# Epoch 167/500
# 7/7 - 0s - loss: 0.2461 - accuracy: 0.8976 - 54ms/epoch - 8ms/step
# Epoch 168/500
# 7/7 - 0s - loss: 0.2448 - accuracy: 0.9048 - 47ms/epoch - 7ms/step
# Epoch 169/500
# 7/7 - 0s - loss: 0.2389 - accuracy: 0.9096 - 47ms/epoch - 7ms/step
# Epoch 170/500
# 7/7 - 0s - loss: 0.2454 - accuracy: 0.9078 - 47ms/epoch - 7ms/step
# Epoch 171/500
# 7/7 - 0s - loss: 0.2333 - accuracy: 0.9066 - 48ms/epoch - 7ms/step
# Epoch 172/500
# 7/7 - 0s - loss: 0.2360 - accuracy: 0.9090 - 47ms/epoch - 7ms/step
# Epoch 173/500
# 7/7 - 0s - loss: 0.2351 - accuracy: 0.9066 - 55ms/epoch - 8ms/step
# Epoch 174/500
# 7/7 - 0s - loss: 0.2311 - accuracy: 0.9102 - 59ms/epoch - 8ms/step
# Epoch 175/500
# 7/7 - 0s - loss: 0.2314 - accuracy: 0.9150 - 49ms/epoch - 7ms/step
# Epoch 176/500
# 7/7 - 0s - loss: 0.2222 - accuracy: 0.9186 - 50ms/epoch - 7ms/step
# Epoch 177/500
# 7/7 - 0s - loss: 0.2293 - accuracy: 0.9096 - 48ms/epoch - 7ms/step
# Epoch 178/500
# 7/7 - 0s - loss: 0.2276 - accuracy: 0.9126 - 51ms/epoch - 7ms/step
# Epoch 179/500
# 7/7 - 0s - loss: 0.2447 - accuracy: 0.9096 - 46ms/epoch - 7ms/step
# Epoch 180/500
# 7/7 - 0s - loss: 0.2366 - accuracy: 0.8982 - 45ms/epoch - 6ms/step
# Epoch 181/500
# 7/7 - 0s - loss: 0.2314 - accuracy: 0.9120 - 47ms/epoch - 7ms/step
# Epoch 182/500
# 7/7 - 0s - loss: 0.2319 - accuracy: 0.9198 - 48ms/epoch - 7ms/step
# Epoch 183/500
# 7/7 - 0s - loss: 0.2373 - accuracy: 0.9078 - 47ms/epoch - 7ms/step
# Epoch 184/500
# 7/7 - 0s - loss: 0.2226 - accuracy: 0.9180 - 56ms/epoch - 8ms/step
# Epoch 185/500
# 7/7 - 0s - loss: 0.2252 - accuracy: 0.9042 - 49ms/epoch - 7ms/step
# Epoch 186/500
# 7/7 - 0s - loss: 0.2211 - accuracy: 0.9144 - 48ms/epoch - 7ms/step
# Epoch 187/500
# 7/7 - 0s - loss: 0.2406 - accuracy: 0.9024 - 47ms/epoch - 7ms/step
# Epoch 188/500
# 7/7 - 0s - loss: 0.2355 - accuracy: 0.9120 - 46ms/epoch - 7ms/step
# Epoch 189/500
# 7/7 - 0s - loss: 0.2271 - accuracy: 0.9054 - 52ms/epoch - 7ms/step
# Epoch 190/500
# 7/7 - 0s - loss: 0.2131 - accuracy: 0.9222 - 48ms/epoch - 7ms/step
# Epoch 191/500
# 7/7 - 0s - loss: 0.2110 - accuracy: 0.9186 - 47ms/epoch - 7ms/step
# Epoch 192/500
# 7/7 - 0s - loss: 0.2097 - accuracy: 0.9168 - 47ms/epoch - 7ms/step
# Epoch 193/500
# 7/7 - 0s - loss: 0.2231 - accuracy: 0.9138 - 62ms/epoch - 9ms/step
# Epoch 194/500
# 7/7 - 0s - loss: 0.2270 - accuracy: 0.9036 - 51ms/epoch - 7ms/step
# Epoch 195/500
# 7/7 - 0s - loss: 0.2374 - accuracy: 0.9084 - 50ms/epoch - 7ms/step
# Epoch 196/500
# 7/7 - 0s - loss: 0.2278 - accuracy: 0.9126 - 49ms/epoch - 7ms/step
# Epoch 197/500
# 7/7 - 0s - loss: 0.2360 - accuracy: 0.9048 - 50ms/epoch - 7ms/step
# Epoch 198/500
# 7/7 - 0s - loss: 0.2148 - accuracy: 0.9138 - 47ms/epoch - 7ms/step
# Epoch 199/500
# 7/7 - 0s - loss: 0.2170 - accuracy: 0.9114 - 56ms/epoch - 8ms/step
# Epoch 200/500
# 7/7 - 0s - loss: 0.2367 - accuracy: 0.9186 - 47ms/epoch - 7ms/step
# Epoch 201/500
# 7/7 - 0s - loss: 0.2450 - accuracy: 0.9078 - 49ms/epoch - 7ms/step
# Epoch 202/500
# 7/7 - 0s - loss: 0.2328 - accuracy: 0.9108 - 49ms/epoch - 7ms/step
# Epoch 203/500
# 7/7 - 0s - loss: 0.2285 - accuracy: 0.9132 - 53ms/epoch - 8ms/step
# Epoch 204/500
# 7/7 - 0s - loss: 0.2168 - accuracy: 0.9186 - 50ms/epoch - 7ms/step
# Epoch 205/500
# 7/7 - 0s - loss: 0.2294 - accuracy: 0.9072 - 50ms/epoch - 7ms/step
# Epoch 206/500
# 7/7 - 0s - loss: 0.2264 - accuracy: 0.9132 - 50ms/epoch - 7ms/step
# Epoch 207/500
# 7/7 - 0s - loss: 0.2218 - accuracy: 0.9120 - 55ms/epoch - 8ms/step
# Epoch 208/500
# 7/7 - 0s - loss: 0.2174 - accuracy: 0.9222 - 51ms/epoch - 7ms/step
# Epoch 209/500
# 7/7 - 0s - loss: 0.1976 - accuracy: 0.9234 - 47ms/epoch - 7ms/step
# Epoch 210/500
# 7/7 - 0s - loss: 0.2261 - accuracy: 0.9102 - 48ms/epoch - 7ms/step
# Epoch 211/500
# 7/7 - 0s - loss: 0.2094 - accuracy: 0.9198 - 63ms/epoch - 9ms/step
# Epoch 212/500
# 7/7 - 0s - loss: 0.2309 - accuracy: 0.9072 - 51ms/epoch - 7ms/step
# Epoch 213/500
# 7/7 - 0s - loss: 0.2377 - accuracy: 0.9084 - 48ms/epoch - 7ms/step
# Epoch 214/500
# 7/7 - 0s - loss: 0.2072 - accuracy: 0.9234 - 47ms/epoch - 7ms/step
# Epoch 215/500
# 7/7 - 0s - loss: 0.2164 - accuracy: 0.9174 - 50ms/epoch - 7ms/step
# Epoch 216/500
# 7/7 - 0s - loss: 0.2143 - accuracy: 0.9162 - 50ms/epoch - 7ms/step
# Epoch 217/500
# 7/7 - 0s - loss: 0.2115 - accuracy: 0.9132 - 47ms/epoch - 7ms/step
# Epoch 218/500
# 7/7 - 0s - loss: 0.2097 - accuracy: 0.9120 - 47ms/epoch - 7ms/step
# Epoch 219/500
# 7/7 - 0s - loss: 0.2183 - accuracy: 0.9120 - 47ms/epoch - 7ms/step
# Epoch 220/500
# 7/7 - 0s - loss: 0.2171 - accuracy: 0.9078 - 48ms/epoch - 7ms/step
# Epoch 221/500
# 7/7 - 0s - loss: 0.2246 - accuracy: 0.9108 - 57ms/epoch - 8ms/step
# Epoch 222/500
# 7/7 - 0s - loss: 0.2124 - accuracy: 0.9192 - 53ms/epoch - 8ms/step
# Epoch 223/500
# 7/7 - 0s - loss: 0.2144 - accuracy: 0.9150 - 48ms/epoch - 7ms/step
# Epoch 224/500
# 7/7 - 0s - loss: 0.2126 - accuracy: 0.9066 - 50ms/epoch - 7ms/step
# Epoch 225/500
# 7/7 - 0s - loss: 0.2136 - accuracy: 0.9174 - 47ms/epoch - 7ms/step
# Epoch 226/500
# 7/7 - 0s - loss: 0.2109 - accuracy: 0.9144 - 45ms/epoch - 6ms/step
# Epoch 227/500
# 7/7 - 0s - loss: 0.2120 - accuracy: 0.9138 - 53ms/epoch - 8ms/step
# Epoch 228/500
# 7/7 - 0s - loss: 0.2063 - accuracy: 0.9222 - 49ms/epoch - 7ms/step
# Epoch 229/500
# 7/7 - 0s - loss: 0.1982 - accuracy: 0.9246 - 60ms/epoch - 9ms/step
# Epoch 230/500
# 7/7 - 0s - loss: 0.2050 - accuracy: 0.9162 - 50ms/epoch - 7ms/step
# Epoch 231/500
# 7/7 - 0s - loss: 0.2012 - accuracy: 0.9257 - 50ms/epoch - 7ms/step
# Epoch 232/500
# 7/7 - 0s - loss: 0.2113 - accuracy: 0.9156 - 53ms/epoch - 8ms/step
# Epoch 233/500
# 7/7 - 0s - loss: 0.1996 - accuracy: 0.9240 - 51ms/epoch - 7ms/step
# Epoch 234/500
# 7/7 - 0s - loss: 0.2143 - accuracy: 0.9186 - 50ms/epoch - 7ms/step
# Epoch 235/500
# 7/7 - 0s - loss: 0.1991 - accuracy: 0.9198 - 53ms/epoch - 8ms/step
# Epoch 236/500
# 7/7 - 0s - loss: 0.2045 - accuracy: 0.9222 - 52ms/epoch - 7ms/step
# Epoch 237/500
# 7/7 - 0s - loss: 0.2010 - accuracy: 0.9234 - 48ms/epoch - 7ms/step
# Epoch 238/500
# 7/7 - 0s - loss: 0.2091 - accuracy: 0.9168 - 48ms/epoch - 7ms/step
# Epoch 239/500
# 7/7 - 0s - loss: 0.2088 - accuracy: 0.9240 - 49ms/epoch - 7ms/step
# Epoch 240/500
# 7/7 - 0s - loss: 0.2072 - accuracy: 0.9162 - 55ms/epoch - 8ms/step
# Epoch 241/500
# 7/7 - 0s - loss: 0.2087 - accuracy: 0.9257 - 52ms/epoch - 7ms/step
# Epoch 242/500
# 7/7 - 0s - loss: 0.2038 - accuracy: 0.9174 - 49ms/epoch - 7ms/step
# Epoch 243/500
# 7/7 - 0s - loss: 0.1978 - accuracy: 0.9275 - 49ms/epoch - 7ms/step
# Epoch 244/500
# 7/7 - 0s - loss: 0.1993 - accuracy: 0.9269 - 49ms/epoch - 7ms/step
# Epoch 245/500
# 7/7 - 0s - loss: 0.2035 - accuracy: 0.9168 - 46ms/epoch - 7ms/step
# Epoch 246/500
# 7/7 - 0s - loss: 0.1939 - accuracy: 0.9257 - 53ms/epoch - 8ms/step
# Epoch 247/500
# 7/7 - 0s - loss: 0.1999 - accuracy: 0.9281 - 55ms/epoch - 8ms/step
# Epoch 248/500
# 7/7 - 0s - loss: 0.1962 - accuracy: 0.9210 - 51ms/epoch - 7ms/step
# Epoch 249/500
# 7/7 - 0s - loss: 0.2028 - accuracy: 0.9204 - 50ms/epoch - 7ms/step
# Epoch 250/500
# 7/7 - 0s - loss: 0.2001 - accuracy: 0.9257 - 47ms/epoch - 7ms/step
# Epoch 251/500
# 7/7 - 0s - loss: 0.2227 - accuracy: 0.9072 - 47ms/epoch - 7ms/step
# Epoch 252/500
# 7/7 - 0s - loss: 0.2129 - accuracy: 0.9162 - 53ms/epoch - 8ms/step
# Epoch 253/500
# 7/7 - 0s - loss: 0.1975 - accuracy: 0.9246 - 47ms/epoch - 7ms/step
# Epoch 254/500
# 7/7 - 0s - loss: 0.1857 - accuracy: 0.9317 - 47ms/epoch - 7ms/step
# Epoch 255/500
# 7/7 - 0s - loss: 0.2046 - accuracy: 0.9257 - 48ms/epoch - 7ms/step
# Epoch 256/500
# 7/7 - 0s - loss: 0.1975 - accuracy: 0.9234 - 56ms/epoch - 8ms/step
# Epoch 257/500
# 7/7 - 0s - loss: 0.1875 - accuracy: 0.9228 - 49ms/epoch - 7ms/step
# Epoch 258/500
# 7/7 - 0s - loss: 0.1950 - accuracy: 0.9275 - 49ms/epoch - 7ms/step
# Epoch 259/500
# 7/7 - 0s - loss: 0.1846 - accuracy: 0.9323 - 49ms/epoch - 7ms/step
# Epoch 260/500
# 7/7 - 0s - loss: 0.1800 - accuracy: 0.9311 - 48ms/epoch - 7ms/step
# Epoch 261/500
# 7/7 - 0s - loss: 0.1914 - accuracy: 0.9234 - 53ms/epoch - 8ms/step
# Epoch 262/500
# 7/7 - 0s - loss: 0.2103 - accuracy: 0.9210 - 48ms/epoch - 7ms/step
# Epoch 263/500
# 7/7 - 0s - loss: 0.2041 - accuracy: 0.9168 - 47ms/epoch - 7ms/step
# Epoch 264/500
# 7/7 - 0s - loss: 0.2066 - accuracy: 0.9204 - 46ms/epoch - 7ms/step
# Epoch 265/500
# 7/7 - 0s - loss: 0.1900 - accuracy: 0.9275 - 57ms/epoch - 8ms/step
# Epoch 266/500
# 7/7 - 0s - loss: 0.1995 - accuracy: 0.9234 - 63ms/epoch - 9ms/step
# Epoch 267/500
# 7/7 - 0s - loss: 0.1946 - accuracy: 0.9216 - 47ms/epoch - 7ms/step
# Epoch 268/500
# 7/7 - 0s - loss: 0.1999 - accuracy: 0.9198 - 47ms/epoch - 7ms/step
# Epoch 269/500
# 7/7 - 0s - loss: 0.1961 - accuracy: 0.9246 - 50ms/epoch - 7ms/step
# Epoch 270/500
# 7/7 - 0s - loss: 0.1878 - accuracy: 0.9234 - 50ms/epoch - 7ms/step
# Epoch 271/500
# 7/7 - 0s - loss: 0.1831 - accuracy: 0.9269 - 49ms/epoch - 7ms/step
# Epoch 272/500
# 7/7 - 0s - loss: 0.1885 - accuracy: 0.9311 - 49ms/epoch - 7ms/step
# Epoch 273/500
# 7/7 - 0s - loss: 0.1850 - accuracy: 0.9269 - 48ms/epoch - 7ms/step
# Epoch 274/500
# 7/7 - 0s - loss: 0.2026 - accuracy: 0.9228 - 48ms/epoch - 7ms/step
# Epoch 275/500
# 7/7 - 0s - loss: 0.1833 - accuracy: 0.9305 - 50ms/epoch - 7ms/step
# Epoch 276/500
# 7/7 - 0s - loss: 0.1803 - accuracy: 0.9317 - 56ms/epoch - 8ms/step
# Epoch 277/500
# 7/7 - 0s - loss: 0.1813 - accuracy: 0.9311 - 49ms/epoch - 7ms/step
# Epoch 278/500
# 7/7 - 0s - loss: 0.1913 - accuracy: 0.9240 - 49ms/epoch - 7ms/step
# Epoch 279/500
# 7/7 - 0s - loss: 0.1878 - accuracy: 0.9257 - 48ms/epoch - 7ms/step
# Epoch 280/500
# 7/7 - 0s - loss: 0.1744 - accuracy: 0.9341 - 47ms/epoch - 7ms/step
# Epoch 281/500
# 7/7 - 0s - loss: 0.1938 - accuracy: 0.9275 - 46ms/epoch - 7ms/step
# Epoch 282/500
# 7/7 - 0s - loss: 0.1892 - accuracy: 0.9263 - 57ms/epoch - 8ms/step
# Epoch 283/500
# 7/7 - 0s - loss: 0.1924 - accuracy: 0.9257 - 49ms/epoch - 7ms/step
# Epoch 284/500
# 7/7 - 0s - loss: 0.1742 - accuracy: 0.9305 - 57ms/epoch - 8ms/step
# Epoch 285/500
# 7/7 - 0s - loss: 0.1781 - accuracy: 0.9293 - 49ms/epoch - 7ms/step
# Epoch 286/500
# 7/7 - 0s - loss: 0.2023 - accuracy: 0.9240 - 53ms/epoch - 8ms/step
# Epoch 287/500
# 7/7 - 0s - loss: 0.1727 - accuracy: 0.9323 - 49ms/epoch - 7ms/step
# Epoch 288/500
# 7/7 - 0s - loss: 0.1797 - accuracy: 0.9317 - 54ms/epoch - 8ms/step
# Epoch 289/500
# 7/7 - 0s - loss: 0.1791 - accuracy: 0.9317 - 53ms/epoch - 8ms/step
# Epoch 290/500
# 7/7 - 0s - loss: 0.1851 - accuracy: 0.9216 - 55ms/epoch - 8ms/step
# Epoch 291/500
# 7/7 - 0s - loss: 0.1841 - accuracy: 0.9257 - 49ms/epoch - 7ms/step
# Epoch 292/500
# 7/7 - 0s - loss: 0.1910 - accuracy: 0.9293 - 48ms/epoch - 7ms/step
# Epoch 293/500
# 7/7 - 0s - loss: 0.1760 - accuracy: 0.9329 - 47ms/epoch - 7ms/step
# Epoch 294/500
# 7/7 - 0s - loss: 0.1831 - accuracy: 0.9299 - 47ms/epoch - 7ms/step
# Epoch 295/500
# 7/7 - 0s - loss: 0.1795 - accuracy: 0.9287 - 50ms/epoch - 7ms/step
# Epoch 296/500
# 7/7 - 0s - loss: 0.1731 - accuracy: 0.9371 - 48ms/epoch - 7ms/step
# Epoch 297/500
# 7/7 - 0s - loss: 0.1943 - accuracy: 0.9281 - 50ms/epoch - 7ms/step
# Epoch 298/500
# 7/7 - 0s - loss: 0.1704 - accuracy: 0.9419 - 54ms/epoch - 8ms/step
# Epoch 299/500
# 7/7 - 0s - loss: 0.1975 - accuracy: 0.9234 - 48ms/epoch - 7ms/step
# Epoch 300/500
# 7/7 - 0s - loss: 0.1872 - accuracy: 0.9263 - 53ms/epoch - 8ms/step
# Epoch 301/500
# 7/7 - 0s - loss: 0.1993 - accuracy: 0.9257 - 48ms/epoch - 7ms/step
# Epoch 302/500
# 7/7 - 0s - loss: 0.1736 - accuracy: 0.9263 - 50ms/epoch - 7ms/step
# Epoch 303/500
# 7/7 - 0s - loss: 0.1876 - accuracy: 0.9263 - 51ms/epoch - 7ms/step
# Epoch 304/500
# 7/7 - 0s - loss: 0.1803 - accuracy: 0.9293 - 54ms/epoch - 8ms/step
# Epoch 305/500
# 7/7 - 0s - loss: 0.1906 - accuracy: 0.9251 - 46ms/epoch - 7ms/step
# Epoch 306/500
# 7/7 - 0s - loss: 0.1944 - accuracy: 0.9240 - 46ms/epoch - 7ms/step
# Epoch 307/500
# 7/7 - 0s - loss: 0.1945 - accuracy: 0.9275 - 50ms/epoch - 7ms/step
# Epoch 308/500
# 7/7 - 0s - loss: 0.1798 - accuracy: 0.9305 - 49ms/epoch - 7ms/step
# Epoch 309/500
# 7/7 - 0s - loss: 0.1828 - accuracy: 0.9365 - 53ms/epoch - 8ms/step
# Epoch 310/500
# 7/7 - 0s - loss: 0.1886 - accuracy: 0.9269 - 47ms/epoch - 7ms/step
# Epoch 311/500
# 7/7 - 0s - loss: 0.1890 - accuracy: 0.9246 - 48ms/epoch - 7ms/step
# Epoch 312/500
# 7/7 - 0s - loss: 0.1946 - accuracy: 0.9281 - 47ms/epoch - 7ms/step
# Epoch 313/500
# 7/7 - 0s - loss: 0.1858 - accuracy: 0.9269 - 48ms/epoch - 7ms/step
# Epoch 314/500
# 7/7 - 0s - loss: 0.2038 - accuracy: 0.9156 - 50ms/epoch - 7ms/step
# Epoch 315/500
# 7/7 - 0s - loss: 0.1761 - accuracy: 0.9311 - 49ms/epoch - 7ms/step
# Epoch 316/500
# 7/7 - 0s - loss: 0.1884 - accuracy: 0.9287 - 50ms/epoch - 7ms/step
# Epoch 317/500
# 7/7 - 0s - loss: 0.1721 - accuracy: 0.9359 - 50ms/epoch - 7ms/step
# Epoch 318/500
# 7/7 - 0s - loss: 0.1637 - accuracy: 0.9329 - 48ms/epoch - 7ms/step
# Epoch 319/500
# 7/7 - 0s - loss: 0.1731 - accuracy: 0.9317 - 52ms/epoch - 7ms/step
# Epoch 320/500
# 7/7 - 0s - loss: 0.1645 - accuracy: 0.9413 - 51ms/epoch - 7ms/step
# Epoch 321/500
# 7/7 - 0s - loss: 0.1948 - accuracy: 0.9263 - 57ms/epoch - 8ms/step
# Epoch 322/500
# 7/7 - 0s - loss: 0.1850 - accuracy: 0.9299 - 50ms/epoch - 7ms/step
# Epoch 323/500
# 7/7 - 0s - loss: 0.1887 - accuracy: 0.9293 - 48ms/epoch - 7ms/step
# Epoch 324/500
# 7/7 - 0s - loss: 0.1794 - accuracy: 0.9305 - 54ms/epoch - 8ms/step
# Epoch 325/500
# 7/7 - 0s - loss: 0.1917 - accuracy: 0.9222 - 49ms/epoch - 7ms/step
# Epoch 326/500
# 7/7 - 0s - loss: 0.1755 - accuracy: 0.9311 - 50ms/epoch - 7ms/step
# Epoch 327/500
# 7/7 - 0s - loss: 0.1739 - accuracy: 0.9335 - 47ms/epoch - 7ms/step
# Epoch 328/500
# 7/7 - 0s - loss: 0.1833 - accuracy: 0.9275 - 52ms/epoch - 7ms/step
# Epoch 329/500
# 7/7 - 0s - loss: 0.1801 - accuracy: 0.9240 - 48ms/epoch - 7ms/step
# Epoch 330/500
# 7/7 - 0s - loss: 0.1790 - accuracy: 0.9335 - 49ms/epoch - 7ms/step
# Epoch 331/500
# 7/7 - 0s - loss: 0.1805 - accuracy: 0.9347 - 48ms/epoch - 7ms/step
# Epoch 332/500
# 7/7 - 0s - loss: 0.1800 - accuracy: 0.9293 - 48ms/epoch - 7ms/step
# Epoch 333/500
# 7/7 - 0s - loss: 0.1924 - accuracy: 0.9216 - 47ms/epoch - 7ms/step
# Epoch 334/500
# 7/7 - 0s - loss: 0.1711 - accuracy: 0.9359 - 58ms/epoch - 8ms/step
# Epoch 335/500
# 7/7 - 0s - loss: 0.1763 - accuracy: 0.9287 - 51ms/epoch - 7ms/step
# Epoch 336/500
# 7/7 - 0s - loss: 0.1737 - accuracy: 0.9323 - 51ms/epoch - 7ms/step
# Epoch 337/500
# 7/7 - 0s - loss: 0.1749 - accuracy: 0.9329 - 88ms/epoch - 13ms/step
# Epoch 338/500
# 7/7 - 0s - loss: 0.1630 - accuracy: 0.9335 - 91ms/epoch - 13ms/step
# Epoch 339/500
# 7/7 - 0s - loss: 0.1768 - accuracy: 0.9341 - 72ms/epoch - 10ms/step
# Epoch 340/500
# 7/7 - 0s - loss: 0.1687 - accuracy: 0.9389 - 68ms/epoch - 10ms/step
# Epoch 341/500
# 7/7 - 0s - loss: 0.1694 - accuracy: 0.9317 - 66ms/epoch - 9ms/step
# Epoch 342/500
# 7/7 - 0s - loss: 0.1689 - accuracy: 0.9347 - 70ms/epoch - 10ms/step
# Epoch 343/500
# 7/7 - 0s - loss: 0.1699 - accuracy: 0.9365 - 70ms/epoch - 10ms/step
# Epoch 344/500
# 7/7 - 0s - loss: 0.1525 - accuracy: 0.9401 - 69ms/epoch - 10ms/step
# Epoch 345/500
# 7/7 - 0s - loss: 0.1732 - accuracy: 0.9335 - 66ms/epoch - 9ms/step
# Epoch 346/500
# 7/7 - 0s - loss: 0.1601 - accuracy: 0.9353 - 65ms/epoch - 9ms/step
# Epoch 347/500
# 7/7 - 0s - loss: 0.1839 - accuracy: 0.9305 - 67ms/epoch - 10ms/step
# Epoch 348/500
# 7/7 - 0s - loss: 0.1788 - accuracy: 0.9341 - 73ms/epoch - 10ms/step
# Epoch 349/500
# 7/7 - 0s - loss: 0.1797 - accuracy: 0.9347 - 73ms/epoch - 10ms/step
# Epoch 350/500
# 7/7 - 0s - loss: 0.1828 - accuracy: 0.9287 - 77ms/epoch - 11ms/step
# Epoch 351/500
# 7/7 - 0s - loss: 0.1701 - accuracy: 0.9329 - 71ms/epoch - 10ms/step
# Epoch 352/500
# 7/7 - 0s - loss: 0.1806 - accuracy: 0.9287 - 84ms/epoch - 12ms/step
# Epoch 353/500
# 7/7 - 0s - loss: 0.1838 - accuracy: 0.9305 - 67ms/epoch - 10ms/step
# Epoch 354/500
# 7/7 - 0s - loss: 0.1766 - accuracy: 0.9281 - 67ms/epoch - 10ms/step
# Epoch 355/500
# 7/7 - 0s - loss: 0.1768 - accuracy: 0.9323 - 71ms/epoch - 10ms/step
# Epoch 356/500
# 7/7 - 0s - loss: 0.1512 - accuracy: 0.9383 - 69ms/epoch - 10ms/step
# Epoch 357/500
# 7/7 - 0s - loss: 0.1703 - accuracy: 0.9425 - 74ms/epoch - 11ms/step
# Epoch 358/500
# 7/7 - 0s - loss: 0.1632 - accuracy: 0.9299 - 73ms/epoch - 10ms/step
# Epoch 359/500
# 7/7 - 0s - loss: 0.1713 - accuracy: 0.9341 - 70ms/epoch - 10ms/step
# Epoch 360/500
# 7/7 - 0s - loss: 0.1750 - accuracy: 0.9311 - 73ms/epoch - 10ms/step
# Epoch 361/500
# 7/7 - 0s - loss: 0.1729 - accuracy: 0.9287 - 70ms/epoch - 10ms/step
# Epoch 362/500
# 7/7 - 0s - loss: 0.1652 - accuracy: 0.9335 - 70ms/epoch - 10ms/step
# Epoch 363/500
# 7/7 - 0s - loss: 0.1733 - accuracy: 0.9359 - 69ms/epoch - 10ms/step
# Epoch 364/500
# 7/7 - 0s - loss: 0.1741 - accuracy: 0.9317 - 71ms/epoch - 10ms/step
# Epoch 365/500
# 7/7 - 0s - loss: 0.1594 - accuracy: 0.9401 - 78ms/epoch - 11ms/step
# Epoch 366/500
# 7/7 - 0s - loss: 0.1733 - accuracy: 0.9323 - 77ms/epoch - 11ms/step
# Epoch 367/500
# 7/7 - 0s - loss: 0.1545 - accuracy: 0.9395 - 72ms/epoch - 10ms/step
# Epoch 368/500
# 7/7 - 0s - loss: 0.1632 - accuracy: 0.9353 - 74ms/epoch - 11ms/step
# Epoch 369/500
# 7/7 - 0s - loss: 0.1571 - accuracy: 0.9431 - 76ms/epoch - 11ms/step
# Epoch 370/500
# 7/7 - 0s - loss: 0.1737 - accuracy: 0.9299 - 75ms/epoch - 11ms/step
# Epoch 371/500
# 7/7 - 0s - loss: 0.1712 - accuracy: 0.9353 - 71ms/epoch - 10ms/step
# Epoch 372/500
# 7/7 - 0s - loss: 0.1698 - accuracy: 0.9365 - 71ms/epoch - 10ms/step
# Epoch 373/500
# 7/7 - 0s - loss: 0.1727 - accuracy: 0.9317 - 64ms/epoch - 9ms/step
# Epoch 374/500
# 7/7 - 0s - loss: 0.1647 - accuracy: 0.9395 - 66ms/epoch - 9ms/step
# Epoch 375/500
# 7/7 - 0s - loss: 0.1792 - accuracy: 0.9353 - 68ms/epoch - 10ms/step
# Epoch 376/500
# 7/7 - 0s - loss: 0.1599 - accuracy: 0.9347 - 69ms/epoch - 10ms/step
# Epoch 377/500
# 7/7 - 0s - loss: 0.1723 - accuracy: 0.9377 - 74ms/epoch - 11ms/step
# Epoch 378/500
# 7/7 - 0s - loss: 0.1619 - accuracy: 0.9437 - 66ms/epoch - 9ms/step
# Epoch 379/500
# 7/7 - 0s - loss: 0.1584 - accuracy: 0.9341 - 75ms/epoch - 11ms/step
# Epoch 380/500
# 7/7 - 0s - loss: 0.1741 - accuracy: 0.9359 - 67ms/epoch - 10ms/step
# Epoch 381/500
# 7/7 - 0s - loss: 0.1852 - accuracy: 0.9329 - 77ms/epoch - 11ms/step
# Epoch 382/500
# 7/7 - 0s - loss: 0.1680 - accuracy: 0.9317 - 72ms/epoch - 10ms/step
# Epoch 383/500
# 7/7 - 0s - loss: 0.1685 - accuracy: 0.9359 - 74ms/epoch - 11ms/step
# Epoch 384/500
# 7/7 - 0s - loss: 0.1537 - accuracy: 0.9347 - 72ms/epoch - 10ms/step
# Epoch 385/500
# 7/7 - 0s - loss: 0.1526 - accuracy: 0.9449 - 74ms/epoch - 11ms/step
# Epoch 386/500
# 7/7 - 0s - loss: 0.1634 - accuracy: 0.9293 - 75ms/epoch - 11ms/step
# Epoch 387/500
# 7/7 - 0s - loss: 0.1760 - accuracy: 0.9335 - 73ms/epoch - 10ms/step
# Epoch 388/500
# 7/7 - 0s - loss: 0.1685 - accuracy: 0.9407 - 75ms/epoch - 11ms/step
# Epoch 389/500
# 7/7 - 0s - loss: 0.1582 - accuracy: 0.9365 - 79ms/epoch - 11ms/step
# Epoch 390/500
# 7/7 - 0s - loss: 0.1561 - accuracy: 0.9401 - 77ms/epoch - 11ms/step
# Epoch 391/500
# 7/7 - 0s - loss: 0.1465 - accuracy: 0.9455 - 76ms/epoch - 11ms/step
# Epoch 392/500
# 7/7 - 0s - loss: 0.1476 - accuracy: 0.9461 - 85ms/epoch - 12ms/step
# Epoch 393/500
# 7/7 - 0s - loss: 0.1557 - accuracy: 0.9407 - 73ms/epoch - 10ms/step
# Epoch 394/500
# 7/7 - 0s - loss: 0.1533 - accuracy: 0.9425 - 79ms/epoch - 11ms/step
# Epoch 395/500
# 7/7 - 0s - loss: 0.1615 - accuracy: 0.9377 - 81ms/epoch - 12ms/step
# Epoch 396/500
# 7/7 - 0s - loss: 0.1523 - accuracy: 0.9425 - 78ms/epoch - 11ms/step
# Epoch 397/500
# 7/7 - 0s - loss: 0.1495 - accuracy: 0.9449 - 76ms/epoch - 11ms/step
# Epoch 398/500
# 7/7 - 0s - loss: 0.1541 - accuracy: 0.9371 - 85ms/epoch - 12ms/step
# Epoch 399/500
# 7/7 - 0s - loss: 0.1648 - accuracy: 0.9383 - 75ms/epoch - 11ms/step
# Epoch 400/500
# 7/7 - 0s - loss: 0.1538 - accuracy: 0.9389 - 75ms/epoch - 11ms/step
# Epoch 401/500
# 7/7 - 0s - loss: 0.1683 - accuracy: 0.9383 - 78ms/epoch - 11ms/step
# Epoch 402/500
# 7/7 - 0s - loss: 0.1681 - accuracy: 0.9359 - 79ms/epoch - 11ms/step
# Epoch 403/500
# 7/7 - 0s - loss: 0.1603 - accuracy: 0.9341 - 73ms/epoch - 10ms/step
# Epoch 404/500
# 7/7 - 0s - loss: 0.1613 - accuracy: 0.9389 - 76ms/epoch - 11ms/step
# Epoch 405/500
# 7/7 - 0s - loss: 0.1443 - accuracy: 0.9467 - 75ms/epoch - 11ms/step
# Epoch 406/500
# 7/7 - 0s - loss: 0.1673 - accuracy: 0.9383 - 81ms/epoch - 12ms/step
# Epoch 407/500
# 7/7 - 0s - loss: 0.1642 - accuracy: 0.9389 - 75ms/epoch - 11ms/step
# Epoch 408/500
# 7/7 - 0s - loss: 0.1619 - accuracy: 0.9419 - 75ms/epoch - 11ms/step
# Epoch 409/500
# 7/7 - 0s - loss: 0.1499 - accuracy: 0.9389 - 76ms/epoch - 11ms/step
# Epoch 410/500
# 7/7 - 0s - loss: 0.1684 - accuracy: 0.9389 - 73ms/epoch - 10ms/step
# Epoch 411/500
# 7/7 - 0s - loss: 0.1638 - accuracy: 0.9371 - 78ms/epoch - 11ms/step
# Epoch 412/500
# 7/7 - 0s - loss: 0.1442 - accuracy: 0.9425 - 82ms/epoch - 12ms/step
# Epoch 413/500
# 7/7 - 0s - loss: 0.1466 - accuracy: 0.9419 - 79ms/epoch - 11ms/step
# Epoch 414/500
# 7/7 - 0s - loss: 0.1464 - accuracy: 0.9407 - 72ms/epoch - 10ms/step
# Epoch 415/500
# 7/7 - 0s - loss: 0.1662 - accuracy: 0.9365 - 72ms/epoch - 10ms/step
# Epoch 416/500
# 7/7 - 0s - loss: 0.1663 - accuracy: 0.9377 - 72ms/epoch - 10ms/step
# Epoch 417/500
# 7/7 - 0s - loss: 0.1669 - accuracy: 0.9365 - 78ms/epoch - 11ms/step
# Epoch 418/500
# 7/7 - 0s - loss: 0.1665 - accuracy: 0.9365 - 77ms/epoch - 11ms/step
# Epoch 419/500
# 7/7 - 0s - loss: 0.1497 - accuracy: 0.9425 - 78ms/epoch - 11ms/step
# Epoch 420/500
# 7/7 - 0s - loss: 0.1605 - accuracy: 0.9329 - 74ms/epoch - 11ms/step
# Epoch 421/500
# 7/7 - 0s - loss: 0.1643 - accuracy: 0.9377 - 71ms/epoch - 10ms/step
# Epoch 422/500
# 7/7 - 0s - loss: 0.1727 - accuracy: 0.9341 - 91ms/epoch - 13ms/step
# Epoch 423/500
# 7/7 - 0s - loss: 0.1682 - accuracy: 0.9305 - 54ms/epoch - 8ms/step
# Epoch 424/500
# 7/7 - 0s - loss: 0.1589 - accuracy: 0.9401 - 55ms/epoch - 8ms/step
# Epoch 425/500
# 7/7 - 0s - loss: 0.1495 - accuracy: 0.9449 - 54ms/epoch - 8ms/step
# Epoch 426/500
# 7/7 - 0s - loss: 0.1415 - accuracy: 0.9491 - 52ms/epoch - 7ms/step
# Epoch 427/500
# 7/7 - 0s - loss: 0.1533 - accuracy: 0.9401 - 51ms/epoch - 7ms/step
# Epoch 428/500
# 7/7 - 0s - loss: 0.1509 - accuracy: 0.9437 - 54ms/epoch - 8ms/step
# Epoch 429/500
# 7/7 - 0s - loss: 0.1499 - accuracy: 0.9431 - 56ms/epoch - 8ms/step
# Epoch 430/500
# 7/7 - 0s - loss: 0.1573 - accuracy: 0.9449 - 50ms/epoch - 7ms/step
# Epoch 431/500
# 7/7 - 0s - loss: 0.1442 - accuracy: 0.9365 - 50ms/epoch - 7ms/step
# Epoch 432/500
# 7/7 - 0s - loss: 0.1571 - accuracy: 0.9419 - 48ms/epoch - 7ms/step
# Epoch 433/500
# 7/7 - 0s - loss: 0.1637 - accuracy: 0.9401 - 56ms/epoch - 8ms/step
# Epoch 434/500
# 7/7 - 0s - loss: 0.1530 - accuracy: 0.9413 - 51ms/epoch - 7ms/step
# Epoch 435/500
# 7/7 - 0s - loss: 0.1588 - accuracy: 0.9425 - 55ms/epoch - 8ms/step
# Epoch 436/500
# 7/7 - 0s - loss: 0.1434 - accuracy: 0.9455 - 51ms/epoch - 7ms/step
# Epoch 437/500
# 7/7 - 0s - loss: 0.1496 - accuracy: 0.9443 - 55ms/epoch - 8ms/step
# Epoch 438/500
# 7/7 - 0s - loss: 0.1578 - accuracy: 0.9383 - 48ms/epoch - 7ms/step
# Epoch 439/500
# 7/7 - 0s - loss: 0.1604 - accuracy: 0.9425 - 49ms/epoch - 7ms/step
# Epoch 440/500
# 7/7 - 0s - loss: 0.1422 - accuracy: 0.9467 - 50ms/epoch - 7ms/step
# Epoch 441/500
# 7/7 - 0s - loss: 0.1589 - accuracy: 0.9395 - 52ms/epoch - 7ms/step
# Epoch 442/500
# 7/7 - 0s - loss: 0.1509 - accuracy: 0.9377 - 48ms/epoch - 7ms/step
# Epoch 443/500
# 7/7 - 0s - loss: 0.1581 - accuracy: 0.9359 - 54ms/epoch - 8ms/step
# Epoch 444/500
# 7/7 - 0s - loss: 0.1615 - accuracy: 0.9365 - 51ms/epoch - 7ms/step
# Epoch 445/500
# 7/7 - 0s - loss: 0.1492 - accuracy: 0.9473 - 54ms/epoch - 8ms/step
# Epoch 446/500
# 7/7 - 0s - loss: 0.1442 - accuracy: 0.9467 - 51ms/epoch - 7ms/step
# Epoch 447/500
# 7/7 - 0s - loss: 0.1559 - accuracy: 0.9461 - 49ms/epoch - 7ms/step
# Epoch 448/500
# 7/7 - 0s - loss: 0.1463 - accuracy: 0.9413 - 49ms/epoch - 7ms/step
# Epoch 449/500
# 7/7 - 0s - loss: 0.1505 - accuracy: 0.9479 - 48ms/epoch - 7ms/step
# Epoch 450/500
# 7/7 - 0s - loss: 0.1630 - accuracy: 0.9335 - 58ms/epoch - 8ms/step
# Epoch 451/500
# 7/7 - 0s - loss: 0.1321 - accuracy: 0.9461 - 51ms/epoch - 7ms/step
# Epoch 452/500
# 7/7 - 0s - loss: 0.1493 - accuracy: 0.9455 - 52ms/epoch - 7ms/step
# Epoch 453/500
# 7/7 - 0s - loss: 0.1402 - accuracy: 0.9389 - 49ms/epoch - 7ms/step
# Epoch 454/500
# 7/7 - 0s - loss: 0.1425 - accuracy: 0.9479 - 51ms/epoch - 7ms/step
# Epoch 455/500
# 7/7 - 0s - loss: 0.1393 - accuracy: 0.9515 - 58ms/epoch - 8ms/step
# Epoch 456/500
# 7/7 - 0s - loss: 0.1365 - accuracy: 0.9497 - 48ms/epoch - 7ms/step
# Epoch 457/500
# 7/7 - 0s - loss: 0.1463 - accuracy: 0.9491 - 48ms/epoch - 7ms/step
# Epoch 458/500
# 7/7 - 0s - loss: 0.1610 - accuracy: 0.9383 - 48ms/epoch - 7ms/step
# Epoch 459/500
# 7/7 - 0s - loss: 0.1413 - accuracy: 0.9491 - 51ms/epoch - 7ms/step
# Epoch 460/500
# 7/7 - 0s - loss: 0.1512 - accuracy: 0.9419 - 54ms/epoch - 8ms/step
# Epoch 461/500
# 7/7 - 0s - loss: 0.1473 - accuracy: 0.9443 - 49ms/epoch - 7ms/step
# Epoch 462/500
# 7/7 - 0s - loss: 0.1513 - accuracy: 0.9383 - 51ms/epoch - 7ms/step
# Epoch 463/500
# 7/7 - 0s - loss: 0.1458 - accuracy: 0.9467 - 53ms/epoch - 8ms/step
# Epoch 464/500
# 7/7 - 0s - loss: 0.1536 - accuracy: 0.9401 - 51ms/epoch - 7ms/step
# Epoch 465/500
# 7/7 - 0s - loss: 0.1429 - accuracy: 0.9431 - 47ms/epoch - 7ms/step
# Epoch 466/500
# 7/7 - 0s - loss: 0.1364 - accuracy: 0.9509 - 48ms/epoch - 7ms/step
# Epoch 467/500
# 7/7 - 0s - loss: 0.1402 - accuracy: 0.9491 - 56ms/epoch - 8ms/step
# Epoch 468/500
# 7/7 - 0s - loss: 0.1482 - accuracy: 0.9437 - 49ms/epoch - 7ms/step
# Epoch 469/500
# 7/7 - 0s - loss: 0.1432 - accuracy: 0.9431 - 48ms/epoch - 7ms/step
# Epoch 470/500
# 7/7 - 0s - loss: 0.1488 - accuracy: 0.9407 - 46ms/epoch - 7ms/step
# Epoch 471/500
# 7/7 - 0s - loss: 0.1483 - accuracy: 0.9437 - 50ms/epoch - 7ms/step
# Epoch 472/500
# 7/7 - 0s - loss: 0.1301 - accuracy: 0.9479 - 51ms/epoch - 7ms/step
# Epoch 473/500
# 7/7 - 0s - loss: 0.1416 - accuracy: 0.9443 - 56ms/epoch - 8ms/step
# Epoch 474/500
# 7/7 - 0s - loss: 0.1285 - accuracy: 0.9503 - 48ms/epoch - 7ms/step
# Epoch 475/500
# 7/7 - 0s - loss: 0.1412 - accuracy: 0.9413 - 50ms/epoch - 7ms/step
# Epoch 476/500
# 7/7 - 0s - loss: 0.1413 - accuracy: 0.9479 - 51ms/epoch - 7ms/step
# Epoch 477/500
# 7/7 - 0s - loss: 0.1657 - accuracy: 0.9323 - 50ms/epoch - 7ms/step
# Epoch 478/500
# 7/7 - 0s - loss: 0.1544 - accuracy: 0.9341 - 46ms/epoch - 7ms/step
# Epoch 479/500
# 7/7 - 0s - loss: 0.1377 - accuracy: 0.9533 - 49ms/epoch - 7ms/step
# Epoch 480/500
# 7/7 - 0s - loss: 0.1366 - accuracy: 0.9491 - 54ms/epoch - 8ms/step
# Epoch 481/500
# 7/7 - 0s - loss: 0.1691 - accuracy: 0.9353 - 49ms/epoch - 7ms/step
# Epoch 482/500
# 7/7 - 0s - loss: 0.1473 - accuracy: 0.9467 - 49ms/epoch - 7ms/step
# Epoch 483/500
# 7/7 - 0s - loss: 0.1514 - accuracy: 0.9413 - 56ms/epoch - 8ms/step
# Epoch 484/500
# 7/7 - 0s - loss: 0.1565 - accuracy: 0.9365 - 50ms/epoch - 7ms/step
# Epoch 485/500
# 7/7 - 0s - loss: 0.1475 - accuracy: 0.9443 - 50ms/epoch - 7ms/step
# Epoch 486/500
# 7/7 - 0s - loss: 0.1502 - accuracy: 0.9473 - 47ms/epoch - 7ms/step
# Epoch 487/500
# 7/7 - 0s - loss: 0.1565 - accuracy: 0.9401 - 59ms/epoch - 8ms/step
# Epoch 488/500
# 7/7 - 0s - loss: 0.1396 - accuracy: 0.9449 - 48ms/epoch - 7ms/step
# Epoch 489/500
# 7/7 - 0s - loss: 0.1455 - accuracy: 0.9467 - 49ms/epoch - 7ms/step
# Epoch 490/500
# 7/7 - 0s - loss: 0.1382 - accuracy: 0.9431 - 53ms/epoch - 8ms/step
# Epoch 491/500
# 7/7 - 0s - loss: 0.1407 - accuracy: 0.9509 - 49ms/epoch - 7ms/step
# Epoch 492/500
# 7/7 - 0s - loss: 0.1530 - accuracy: 0.9443 - 54ms/epoch - 8ms/step
# Epoch 493/500
# 7/7 - 0s - loss: 0.1484 - accuracy: 0.9443 - 50ms/epoch - 7ms/step
# Epoch 494/500
# 7/7 - 0s - loss: 0.1335 - accuracy: 0.9467 - 48ms/epoch - 7ms/step
# Epoch 495/500
# 7/7 - 0s - loss: 0.1301 - accuracy: 0.9497 - 49ms/epoch - 7ms/step
# Epoch 496/500
# 7/7 - 0s - loss: 0.1487 - accuracy: 0.9413 - 47ms/epoch - 7ms/step
# Epoch 497/500
# 7/7 - 0s - loss: 0.1360 - accuracy: 0.9467 - 54ms/epoch - 8ms/step
# Epoch 498/500
# 7/7 - 0s - loss: 0.1400 - accuracy: 0.9503 - 47ms/epoch - 7ms/step
# Epoch 499/500
# 7/7 - 0s - loss: 0.1430 - accuracy: 0.9455 - 49ms/epoch - 7ms/step
# Epoch 500/500
# 7/7 - 0s - loss: 0.1310 - accuracy: 0.9455 - 47ms/epoch - 7ms/step
# 14/14 [==============================] - 1s 11ms/step
# 14/14 [==============================] - 0s 3ms/step
# 14/14 [==============================] - 0s 3ms/step
#               precision    recall  f1-score   support
#
#            1     0.8924    0.9592    0.9246       147
#            2     0.9868    1.0000    0.9933       149
#            3     0.0000    0.0000    0.0000         0
#
#    micro avg     0.9385    0.9797    0.9587       296
#    macro avg     0.6264    0.6531    0.6393       296
# weighted avg     0.9399    0.9797    0.9592       296
#
# accuracy_score: 0.9402
#
# ---------------------------------------------------------------------------------
# Train runtime: 0.2970612049102783
# 14/14 [==============================] - 0s 4ms/step - loss: 0.2064 - accuracy: 0.9402
# 14/14 [==============================] - 0s 3ms/step
# Test runtime: 0.598186731338501
# 14/14 [==============================] - 0s 3ms/step
# 14/14 [==============================] - 0s 4ms/step - loss: 0.2064 - accuracy: 0.9402
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2064 - accuracy: 0.9402
# 14/14 [==============================] - 0s 2ms/step
# 14/14 [==============================] - 0s 4ms/step - loss: 0.2064 - accuracy: 0.9402
# 14/14 [==============================] - 0s 2ms/step
